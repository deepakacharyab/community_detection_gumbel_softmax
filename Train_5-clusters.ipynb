# %%
import pandas as pd 
from sklearn import preprocessing 
data = pd.read_csv("datasets/train.csv") 
import networkx as nx
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import math
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from modularity_maximization import partition
from modularity_maximization.utils import get_modularity
from modutils import mod_calc
device = torch.device('cpu')

# %%
G = nx.Graph()
G.add_edges_from(data.values)

comm_dict = partition(G)
clusters_number = len(np.array(list(set(comm_dict.values()))))

# %%
A_hat = nx.adjacency_matrix(G).todense()
X = np.identity(G.number_of_nodes(), dtype=np.float)

# %%
class CDCGS(nn.Module):
    def __init__(self, A_hat, num_feat, num_hidden):
        super(CDCGS, self).__init__()
        self.num_feat = num_feat
        self.num_hidden = num_hidden
        self.A_hat = A_hat
        self.W_0 = nn.Parameter(torch.ones(num_feat, num_hidden))
        I = F.one_hot(torch.tensor(random.sample(range(0, num_feat), num_feat)), num_classes=num_feat)
        self.I = torch.tensor(I,dtype=torch.float)

    def forward(self, X, A_hat,temp):
        global featureSelector
        global weight_feature
        featureSelector = self.W_0
        results = torch.zeros(self.W_0.size())
        x = 500
        for i in range(x):
            results += F.gumbel_softmax(self.W_0,tau=temp,hard=False)
        weight_feature = results/x

        H = torch.mm(torch.mm(self.I,A_hat),self.I.T)
        H = torch.mm(torch.mm(weight_feature.T,A_hat),weight_feature)
        H = torch.div(H, H.sum(axis=0))
        m = nn.Softmax(dim=0)
        return m(H)

num_feat = len(G.nodes())
num_hidden = clusters_number

model = CDCGS(A_hat, num_feat, num_hidden).to(device)

def lossFn(output,exp): 
    return torch.sum((torch.diag(-torch.log(output))))

optimizer = optim.Adam(model.parameters(),lr=3e-2,weight_decay=0,betas=(0.5, 0.999), eps=1e-08)


A_hat_tensor = torch.Tensor(A_hat).to(device)
X_tensor = torch.Tensor(X).to(device)

loss_hist = []
acc_hist = []
temp = 3

for epoch in range(400):
    model.train()
    model.zero_grad()
    if(epoch == 75):
        temp = 2.75
    elif(epoch == 100):
        temp = 2.5
    elif(epoch == 125):
        temp = 2
    elif(epoch == 150):
        temp = 1.8
    elif(epoch == 175):
        temp = 1.25
    elif(epoch == 250):
        temp = 1.00
    elif(epoch == 300):
        temp = 0.75
    elif(epoch == 320):
        temp = 0.5
    output = model(X_tensor, A_hat_tensor,temp)
    loss = lossFn(output,torch.diag(torch.ones(output.size()[0])))
    loss_hist.append(loss.item())
    print('loss',epoch,loss)
    loss.backward()
    optimizer.step()
# Out:
# /opt/anaconda/envs/Deepak/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':
# loss 0 tensor(8.0472, grad_fn=<SumBackward0>)
# loss 1 tensor(8.0472, grad_fn=<SumBackward0>)
# loss 2 tensor(8.0471, grad_fn=<SumBackward0>)
# loss 3 tensor(8.0470, grad_fn=<SumBackward0>)
# loss 4 tensor(8.0467, grad_fn=<SumBackward0>)
# loss 5 tensor(8.0465, grad_fn=<SumBackward0>)
# loss 6 tensor(8.0458, grad_fn=<SumBackward0>)
# loss 7 tensor(8.0452, grad_fn=<SumBackward0>)
# loss 8 tensor(8.0443, grad_fn=<SumBackward0>)
# loss 9 tensor(8.0433, grad_fn=<SumBackward0>)
# loss 10 tensor(8.0417, grad_fn=<SumBackward0>)
# loss 11 tensor(8.0404, grad_fn=<SumBackward0>)
# loss 12 tensor(8.0385, grad_fn=<SumBackward0>)
# loss 13 tensor(8.0365, grad_fn=<SumBackward0>)
# loss 14 tensor(8.0338, grad_fn=<SumBackward0>)
# loss 15 tensor(8.0311, grad_fn=<SumBackward0>)
# loss 16 tensor(8.0287, grad_fn=<SumBackward0>)
# loss 17 tensor(8.0257, grad_fn=<SumBackward0>)
# loss 18 tensor(8.0224, grad_fn=<SumBackward0>)
# loss 19 tensor(8.0192, grad_fn=<SumBackward0>)
# loss 20 tensor(8.0154, grad_fn=<SumBackward0>)
# loss 21 tensor(8.0113, grad_fn=<SumBackward0>)
# loss 22 tensor(8.0074, grad_fn=<SumBackward0>)
# loss 23 tensor(8.0022, grad_fn=<SumBackward0>)
# loss 24 tensor(7.9975, grad_fn=<SumBackward0>)
# loss 25 tensor(7.9937, grad_fn=<SumBackward0>)
# loss 26 tensor(7.9875, grad_fn=<SumBackward0>)
# loss 27 tensor(7.9829, grad_fn=<SumBackward0>)
# loss 28 tensor(7.9766, grad_fn=<SumBackward0>)
# loss 29 tensor(7.9721, grad_fn=<SumBackward0>)
# loss 30 tensor(7.9654, grad_fn=<SumBackward0>)
# loss 31 tensor(7.9595, grad_fn=<SumBackward0>)
# loss 32 tensor(7.9530, grad_fn=<SumBackward0>)
# loss 33 tensor(7.9464, grad_fn=<SumBackward0>)
# loss 34 tensor(7.9393, grad_fn=<SumBackward0>)
# loss 35 tensor(7.9308, grad_fn=<SumBackward0>)
# loss 36 tensor(7.9254, grad_fn=<SumBackward0>)
# loss 37 tensor(7.9168, grad_fn=<SumBackward0>)
# loss 38 tensor(7.9090, grad_fn=<SumBackward0>)
# loss 39 tensor(7.9007, grad_fn=<SumBackward0>)
# loss 40 tensor(7.8911, grad_fn=<SumBackward0>)
# loss 41 tensor(7.8832, grad_fn=<SumBackward0>)
# loss 42 tensor(7.8760, grad_fn=<SumBackward0>)
# loss 43 tensor(7.8657, grad_fn=<SumBackward0>)
# loss 44 tensor(7.8561, grad_fn=<SumBackward0>)
# loss 45 tensor(7.8486, grad_fn=<SumBackward0>)
# loss 46 tensor(7.8370, grad_fn=<SumBackward0>)
# loss 47 tensor(7.8298, grad_fn=<SumBackward0>)
# loss 48 tensor(7.8215, grad_fn=<SumBackward0>)
# loss 49 tensor(7.8080, grad_fn=<SumBackward0>)
# loss 50 tensor(7.8010, grad_fn=<SumBackward0>)
# loss 51 tensor(7.7875, grad_fn=<SumBackward0>)
# loss 52 tensor(7.7787, grad_fn=<SumBackward0>)
# loss 53 tensor(7.7652, grad_fn=<SumBackward0>)
# loss 54 tensor(7.7575, grad_fn=<SumBackward0>)
# loss 55 tensor(7.7462, grad_fn=<SumBackward0>)
# loss 56 tensor(7.7352, grad_fn=<SumBackward0>)
# loss 57 tensor(7.7236, grad_fn=<SumBackward0>)
# loss 58 tensor(7.7135, grad_fn=<SumBackward0>)
# loss 59 tensor(7.7018, grad_fn=<SumBackward0>)
# loss 60 tensor(7.6894, grad_fn=<SumBackward0>)
# loss 61 tensor(7.6784, grad_fn=<SumBackward0>)
# loss 62 tensor(7.6687, grad_fn=<SumBackward0>)
# loss 63 tensor(7.6550, grad_fn=<SumBackward0>)
# loss 64 tensor(7.6411, grad_fn=<SumBackward0>)
# loss 65 tensor(7.6306, grad_fn=<SumBackward0>)
# loss 66 tensor(7.6148, grad_fn=<SumBackward0>)
# loss 67 tensor(7.6030, grad_fn=<SumBackward0>)
# loss 68 tensor(7.5898, grad_fn=<SumBackward0>)
# loss 69 tensor(7.5759, grad_fn=<SumBackward0>)
# loss 70 tensor(7.5626, grad_fn=<SumBackward0>)
# loss 71 tensor(7.5476, grad_fn=<SumBackward0>)
# loss 72 tensor(7.5301, grad_fn=<SumBackward0>)
# loss 73 tensor(7.5143, grad_fn=<SumBackward0>)
# loss 74 tensor(7.5001, grad_fn=<SumBackward0>)
# loss 75 tensor(7.4110, grad_fn=<SumBackward0>)
# loss 76 tensor(7.3890, grad_fn=<SumBackward0>)
# loss 77 tensor(7.3666, grad_fn=<SumBackward0>)
# loss 78 tensor(7.3447, grad_fn=<SumBackward0>)
# loss 79 tensor(7.3194, grad_fn=<SumBackward0>)
# loss 80 tensor(7.2982, grad_fn=<SumBackward0>)
# loss 81 tensor(7.2761, grad_fn=<SumBackward0>)
# loss 82 tensor(7.2488, grad_fn=<SumBackward0>)
# loss 83 tensor(7.2235, grad_fn=<SumBackward0>)
# loss 84 tensor(7.2018, grad_fn=<SumBackward0>)
# loss 85 tensor(7.1788, grad_fn=<SumBackward0>)
# loss 86 tensor(7.1533, grad_fn=<SumBackward0>)
# loss 87 tensor(7.1280, grad_fn=<SumBackward0>)
# loss 88 tensor(7.1027, grad_fn=<SumBackward0>)
# loss 89 tensor(7.0797, grad_fn=<SumBackward0>)
# loss 90 tensor(7.0529, grad_fn=<SumBackward0>)
# loss 91 tensor(7.0352, grad_fn=<SumBackward0>)
# loss 92 tensor(7.0095, grad_fn=<SumBackward0>)
# loss 93 tensor(6.9871, grad_fn=<SumBackward0>)
# loss 94 tensor(6.9592, grad_fn=<SumBackward0>)
# loss 95 tensor(6.9391, grad_fn=<SumBackward0>)
# loss 96 tensor(6.9191, grad_fn=<SumBackward0>)
# loss 97 tensor(6.8987, grad_fn=<SumBackward0>)
# loss 98 tensor(6.8766, grad_fn=<SumBackward0>)
# loss 99 tensor(6.8542, grad_fn=<SumBackward0>)
# loss 100 tensor(6.7049, grad_fn=<SumBackward0>)
# loss 101 tensor(6.6886, grad_fn=<SumBackward0>)
# loss 102 tensor(6.6648, grad_fn=<SumBackward0>)
# loss 103 tensor(6.6444, grad_fn=<SumBackward0>)
# loss 104 tensor(6.6281, grad_fn=<SumBackward0>)
# loss 105 tensor(6.6113, grad_fn=<SumBackward0>)
# loss 106 tensor(6.5895, grad_fn=<SumBackward0>)
# loss 107 tensor(6.5765, grad_fn=<SumBackward0>)
# loss 108 tensor(6.5588, grad_fn=<SumBackward0>)
# loss 109 tensor(6.5412, grad_fn=<SumBackward0>)
# loss 110 tensor(6.5280, grad_fn=<SumBackward0>)
# loss 111 tensor(6.5136, grad_fn=<SumBackward0>)
# loss 112 tensor(6.4947, grad_fn=<SumBackward0>)
# loss 113 tensor(6.4822, grad_fn=<SumBackward0>)
# loss 114 tensor(6.4685, grad_fn=<SumBackward0>)
# loss 115 tensor(6.4565, grad_fn=<SumBackward0>)
# loss 116 tensor(6.4416, grad_fn=<SumBackward0>)
# loss 117 tensor(6.4284, grad_fn=<SumBackward0>)
# loss 118 tensor(6.4141, grad_fn=<SumBackward0>)
# loss 119 tensor(6.4031, grad_fn=<SumBackward0>)
# loss 120 tensor(6.3910, grad_fn=<SumBackward0>)
# loss 121 tensor(6.3808, grad_fn=<SumBackward0>)
# loss 122 tensor(6.3676, grad_fn=<SumBackward0>)
# loss 123 tensor(6.3591, grad_fn=<SumBackward0>)
# loss 124 tensor(6.3488, grad_fn=<SumBackward0>)
# loss 125 tensor(6.1229, grad_fn=<SumBackward0>)
# loss 126 tensor(6.1171, grad_fn=<SumBackward0>)
# loss 127 tensor(6.1096, grad_fn=<SumBackward0>)
# loss 128 tensor(6.1026, grad_fn=<SumBackward0>)
# loss 129 tensor(6.0951, grad_fn=<SumBackward0>)
# loss 130 tensor(6.0908, grad_fn=<SumBackward0>)
# loss 131 tensor(6.0838, grad_fn=<SumBackward0>)
# loss 132 tensor(6.0779, grad_fn=<SumBackward0>)
# loss 133 tensor(6.0706, grad_fn=<SumBackward0>)
# loss 134 tensor(6.0682, grad_fn=<SumBackward0>)
# loss 135 tensor(6.0599, grad_fn=<SumBackward0>)
# loss 136 tensor(6.0550, grad_fn=<SumBackward0>)
# loss 137 tensor(6.0477, grad_fn=<SumBackward0>)
# loss 138 tensor(6.0418, grad_fn=<SumBackward0>)
# loss 139 tensor(6.0385, grad_fn=<SumBackward0>)
# loss 140 tensor(6.0316, grad_fn=<SumBackward0>)
# loss 141 tensor(6.0277, grad_fn=<SumBackward0>)
# loss 142 tensor(6.0216, grad_fn=<SumBackward0>)
# loss 143 tensor(6.0196, grad_fn=<SumBackward0>)
# loss 144 tensor(6.0134, grad_fn=<SumBackward0>)
# loss 145 tensor(6.0082, grad_fn=<SumBackward0>)
# loss 146 tensor(6.0039, grad_fn=<SumBackward0>)
# loss 147 tensor(6.0002, grad_fn=<SumBackward0>)
# loss 148 tensor(5.9962, grad_fn=<SumBackward0>)
# loss 149 tensor(5.9917, grad_fn=<SumBackward0>)
# loss 150 tensor(5.9336, grad_fn=<SumBackward0>)
# loss 151 tensor(5.9295, grad_fn=<SumBackward0>)
# loss 152 tensor(5.9274, grad_fn=<SumBackward0>)
# loss 153 tensor(5.9244, grad_fn=<SumBackward0>)
# loss 154 tensor(5.9251, grad_fn=<SumBackward0>)
# loss 155 tensor(5.9188, grad_fn=<SumBackward0>)
# loss 156 tensor(5.9158, grad_fn=<SumBackward0>)
# loss 157 tensor(5.9133, grad_fn=<SumBackward0>)
# loss 158 tensor(5.9122, grad_fn=<SumBackward0>)
# loss 159 tensor(5.9101, grad_fn=<SumBackward0>)
# loss 160 tensor(5.9093, grad_fn=<SumBackward0>)
# loss 161 tensor(5.9063, grad_fn=<SumBackward0>)
# loss 162 tensor(5.9047, grad_fn=<SumBackward0>)
# loss 163 tensor(5.9026, grad_fn=<SumBackward0>)
# loss 164 tensor(5.9000, grad_fn=<SumBackward0>)
# loss 165 tensor(5.8985, grad_fn=<SumBackward0>)
# loss 166 tensor(5.8952, grad_fn=<SumBackward0>)
# loss 167 tensor(5.8948, grad_fn=<SumBackward0>)
# loss 168 tensor(5.8927, grad_fn=<SumBackward0>)
# loss 169 tensor(5.8901, grad_fn=<SumBackward0>)
# loss 170 tensor(5.8886, grad_fn=<SumBackward0>)
# loss 171 tensor(5.8862, grad_fn=<SumBackward0>)
# loss 172 tensor(5.8845, grad_fn=<SumBackward0>)
# loss 173 tensor(5.8829, grad_fn=<SumBackward0>)
# loss 174 tensor(5.8811, grad_fn=<SumBackward0>)
# loss 175 tensor(5.8132, grad_fn=<SumBackward0>)
# loss 176 tensor(5.8125, grad_fn=<SumBackward0>)
# loss 177 tensor(5.8115, grad_fn=<SumBackward0>)
# loss 178 tensor(5.8101, grad_fn=<SumBackward0>)
# loss 179 tensor(5.8078, grad_fn=<SumBackward0>)
# loss 180 tensor(5.8066, grad_fn=<SumBackward0>)
# loss 181 tensor(5.8054, grad_fn=<SumBackward0>)
# loss 182 tensor(5.8036, grad_fn=<SumBackward0>)
# loss 183 tensor(5.8016, grad_fn=<SumBackward0>)
# loss 184 tensor(5.8007, grad_fn=<SumBackward0>)
# loss 185 tensor(5.7973, grad_fn=<SumBackward0>)
# loss 186 tensor(5.7963, grad_fn=<SumBackward0>)
# loss 187 tensor(5.7945, grad_fn=<SumBackward0>)
# loss 188 tensor(5.7921, grad_fn=<SumBackward0>)
# loss 189 tensor(5.7885, grad_fn=<SumBackward0>)
# loss 190 tensor(5.7873, grad_fn=<SumBackward0>)
# loss 191 tensor(5.7840, grad_fn=<SumBackward0>)
# loss 192 tensor(5.7829, grad_fn=<SumBackward0>)
# loss 193 tensor(5.7810, grad_fn=<SumBackward0>)
# loss 194 tensor(5.7777, grad_fn=<SumBackward0>)
# loss 195 tensor(5.7764, grad_fn=<SumBackward0>)
# loss 196 tensor(5.7736, grad_fn=<SumBackward0>)
# loss 197 tensor(5.7726, grad_fn=<SumBackward0>)
# loss 198 tensor(5.7710, grad_fn=<SumBackward0>)
# loss 199 tensor(5.7688, grad_fn=<SumBackward0>)
# loss 200 tensor(5.7678, grad_fn=<SumBackward0>)
# loss 201 tensor(5.7661, grad_fn=<SumBackward0>)
# loss 202 tensor(5.7649, grad_fn=<SumBackward0>)
# loss 203 tensor(5.7648, grad_fn=<SumBackward0>)
# loss 204 tensor(5.7625, grad_fn=<SumBackward0>)
# loss 205 tensor(5.7611, grad_fn=<SumBackward0>)
# loss 206 tensor(5.7599, grad_fn=<SumBackward0>)
# loss 207 tensor(5.7591, grad_fn=<SumBackward0>)
# loss 208 tensor(5.7582, grad_fn=<SumBackward0>)
# loss 209 tensor(5.7580, grad_fn=<SumBackward0>)
# loss 210 tensor(5.7571, grad_fn=<SumBackward0>)
# loss 211 tensor(5.7573, grad_fn=<SumBackward0>)
# loss 212 tensor(5.7554, grad_fn=<SumBackward0>)
# loss 213 tensor(5.7545, grad_fn=<SumBackward0>)
# loss 214 tensor(5.7544, grad_fn=<SumBackward0>)
# loss 215 tensor(5.7541, grad_fn=<SumBackward0>)
# loss 216 tensor(5.7533, grad_fn=<SumBackward0>)
# loss 217 tensor(5.7532, grad_fn=<SumBackward0>)
# loss 218 tensor(5.7537, grad_fn=<SumBackward0>)
# loss 219 tensor(5.7511, grad_fn=<SumBackward0>)
# loss 220 tensor(5.7517, grad_fn=<SumBackward0>)
# loss 221 tensor(5.7502, grad_fn=<SumBackward0>)
# loss 222 tensor(5.7512, grad_fn=<SumBackward0>)
# loss 223 tensor(5.7502, grad_fn=<SumBackward0>)
# loss 224 tensor(5.7510, grad_fn=<SumBackward0>)
# loss 225 tensor(5.7505, grad_fn=<SumBackward0>)
# loss 226 tensor(5.7499, grad_fn=<SumBackward0>)
# loss 227 tensor(5.7487, grad_fn=<SumBackward0>)
# loss 228 tensor(5.7493, grad_fn=<SumBackward0>)
# loss 229 tensor(5.7481, grad_fn=<SumBackward0>)
# loss 230 tensor(5.7484, grad_fn=<SumBackward0>)
# loss 231 tensor(5.7477, grad_fn=<SumBackward0>)
# loss 232 tensor(5.7475, grad_fn=<SumBackward0>)
# loss 233 tensor(5.7471, grad_fn=<SumBackward0>)
# loss 234 tensor(5.7480, grad_fn=<SumBackward0>)
# loss 235 tensor(5.7482, grad_fn=<SumBackward0>)
# loss 236 tensor(5.7472, grad_fn=<SumBackward0>)
# loss 237 tensor(5.7479, grad_fn=<SumBackward0>)
# loss 238 tensor(5.7466, grad_fn=<SumBackward0>)
# loss 239 tensor(5.7462, grad_fn=<SumBackward0>)
# loss 240 tensor(5.7462, grad_fn=<SumBackward0>)
# loss 241 tensor(5.7465, grad_fn=<SumBackward0>)
# loss 242 tensor(5.7464, grad_fn=<SumBackward0>)
# loss 243 tensor(5.7454, grad_fn=<SumBackward0>)
# loss 244 tensor(5.7450, grad_fn=<SumBackward0>)
# loss 245 tensor(5.7450, grad_fn=<SumBackward0>)
# loss 246 tensor(5.7457, grad_fn=<SumBackward0>)
# loss 247 tensor(5.7448, grad_fn=<SumBackward0>)
# loss 248 tensor(5.7458, grad_fn=<SumBackward0>)
# loss 249 tensor(5.7446, grad_fn=<SumBackward0>)
# loss 250 tensor(5.7361, grad_fn=<SumBackward0>)
# loss 251 tensor(5.7367, grad_fn=<SumBackward0>)
# loss 252 tensor(5.7361, grad_fn=<SumBackward0>)
# loss 253 tensor(5.7364, grad_fn=<SumBackward0>)
# loss 254 tensor(5.7360, grad_fn=<SumBackward0>)
# loss 255 tensor(5.7361, grad_fn=<SumBackward0>)
# loss 256 tensor(5.7365, grad_fn=<SumBackward0>)
# loss 257 tensor(5.7362, grad_fn=<SumBackward0>)
# loss 258 tensor(5.7371, grad_fn=<SumBackward0>)
# loss 259 tensor(5.7364, grad_fn=<SumBackward0>)
# loss 260 tensor(5.7358, grad_fn=<SumBackward0>)
# loss 261 tensor(5.7356, grad_fn=<SumBackward0>)
# loss 262 tensor(5.7357, grad_fn=<SumBackward0>)
# loss 263 tensor(5.7352, grad_fn=<SumBackward0>)
# loss 264 tensor(5.7359, grad_fn=<SumBackward0>)
# loss 265 tensor(5.7357, grad_fn=<SumBackward0>)
# loss 266 tensor(5.7362, grad_fn=<SumBackward0>)
# loss 267 tensor(5.7364, grad_fn=<SumBackward0>)
# loss 268 tensor(5.7359, grad_fn=<SumBackward0>)
# loss 269 tensor(5.7358, grad_fn=<SumBackward0>)
# loss 270 tensor(5.7353, grad_fn=<SumBackward0>)
# loss 271 tensor(5.7350, grad_fn=<SumBackward0>)
# loss 272 tensor(5.7356, grad_fn=<SumBackward0>)
# loss 273 tensor(5.7355, grad_fn=<SumBackward0>)
# loss 274 tensor(5.7356, grad_fn=<SumBackward0>)
# loss 275 tensor(5.7357, grad_fn=<SumBackward0>)
# loss 276 tensor(5.7358, grad_fn=<SumBackward0>)
# loss 277 tensor(5.7354, grad_fn=<SumBackward0>)
# loss 278 tensor(5.7361, grad_fn=<SumBackward0>)
# loss 279 tensor(5.7360, grad_fn=<SumBackward0>)
# loss 280 tensor(5.7354, grad_fn=<SumBackward0>)
# loss 281 tensor(5.7362, grad_fn=<SumBackward0>)
# loss 282 tensor(5.7348, grad_fn=<SumBackward0>)
# loss 283 tensor(5.7355, grad_fn=<SumBackward0>)
# loss 284 tensor(5.7351, grad_fn=<SumBackward0>)
# loss 285 tensor(5.7350, grad_fn=<SumBackward0>)
# loss 286 tensor(5.7356, grad_fn=<SumBackward0>)
# loss 287 tensor(5.7345, grad_fn=<SumBackward0>)
# loss 288 tensor(5.7346, grad_fn=<SumBackward0>)
# loss 289 tensor(5.7344, grad_fn=<SumBackward0>)
# loss 290 tensor(5.7356, grad_fn=<SumBackward0>)
# loss 291 tensor(5.7345, grad_fn=<SumBackward0>)
# loss 292 tensor(5.7353, grad_fn=<SumBackward0>)
# loss 293 tensor(5.7351, grad_fn=<SumBackward0>)
# loss 294 tensor(5.7355, grad_fn=<SumBackward0>)
# loss 295 tensor(5.7349, grad_fn=<SumBackward0>)
# loss 296 tensor(5.7352, grad_fn=<SumBackward0>)
# loss 297 tensor(5.7346, grad_fn=<SumBackward0>)
# loss 298 tensor(5.7347, grad_fn=<SumBackward0>)
# loss 299 tensor(5.7351, grad_fn=<SumBackward0>)
# loss 300 tensor(5.7322, grad_fn=<SumBackward0>)
# loss 301 tensor(5.7322, grad_fn=<SumBackward0>)
# loss 302 tensor(5.7319, grad_fn=<SumBackward0>)
# loss 303 tensor(5.7325, grad_fn=<SumBackward0>)
# loss 304 tensor(5.7323, grad_fn=<SumBackward0>)
# loss 305 tensor(5.7331, grad_fn=<SumBackward0>)
# loss 306 tensor(5.7324, grad_fn=<SumBackward0>)
# loss 307 tensor(5.7326, grad_fn=<SumBackward0>)
# loss 308 tensor(5.7319, grad_fn=<SumBackward0>)
# loss 309 tensor(5.7321, grad_fn=<SumBackward0>)
# loss 310 tensor(5.7328, grad_fn=<SumBackward0>)
# loss 311 tensor(5.7320, grad_fn=<SumBackward0>)
# loss 312 tensor(5.7322, grad_fn=<SumBackward0>)
# loss 313 tensor(5.7327, grad_fn=<SumBackward0>)
# loss 314 tensor(5.7320, grad_fn=<SumBackward0>)
# loss 315 tensor(5.7321, grad_fn=<SumBackward0>)
# loss 316 tensor(5.7324, grad_fn=<SumBackward0>)
# loss 317 tensor(5.7324, grad_fn=<SumBackward0>)
# loss 318 tensor(5.7333, grad_fn=<SumBackward0>)
# loss 319 tensor(5.7328, grad_fn=<SumBackward0>)
# loss 320 tensor(5.7312, grad_fn=<SumBackward0>)
# loss 321 tensor(5.7317, grad_fn=<SumBackward0>)
# loss 322 tensor(5.7316, grad_fn=<SumBackward0>)
# loss 323 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 324 tensor(5.7312, grad_fn=<SumBackward0>)
# loss 325 tensor(5.7315, grad_fn=<SumBackward0>)
# loss 326 tensor(5.7316, grad_fn=<SumBackward0>)
# loss 327 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 328 tensor(5.7321, grad_fn=<SumBackward0>)
# loss 329 tensor(5.7314, grad_fn=<SumBackward0>)
# loss 330 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 331 tensor(5.7316, grad_fn=<SumBackward0>)
# loss 332 tensor(5.7316, grad_fn=<SumBackward0>)
# loss 333 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 334 tensor(5.7321, grad_fn=<SumBackward0>)
# loss 335 tensor(5.7312, grad_fn=<SumBackward0>)
# loss 336 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 337 tensor(5.7314, grad_fn=<SumBackward0>)
# loss 338 tensor(5.7314, grad_fn=<SumBackward0>)
# loss 339 tensor(5.7319, grad_fn=<SumBackward0>)
# loss 340 tensor(5.7312, grad_fn=<SumBackward0>)
# loss 341 tensor(5.7317, grad_fn=<SumBackward0>)
# loss 342 tensor(5.7315, grad_fn=<SumBackward0>)
# loss 343 tensor(5.7314, grad_fn=<SumBackward0>)
# loss 344 tensor(5.7311, grad_fn=<SumBackward0>)
# loss 345 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 346 tensor(5.7314, grad_fn=<SumBackward0>)
# loss 347 tensor(5.7315, grad_fn=<SumBackward0>)
# loss 348 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 349 tensor(5.7309, grad_fn=<SumBackward0>)
# loss 350 tensor(5.7312, grad_fn=<SumBackward0>)
# loss 351 tensor(5.7314, grad_fn=<SumBackward0>)
# loss 352 tensor(5.7311, grad_fn=<SumBackward0>)
# loss 353 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 354 tensor(5.7308, grad_fn=<SumBackward0>)
# loss 355 tensor(5.7312, grad_fn=<SumBackward0>)
# loss 356 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 357 tensor(5.7312, grad_fn=<SumBackward0>)
# loss 358 tensor(5.7317, grad_fn=<SumBackward0>)
# loss 359 tensor(5.7306, grad_fn=<SumBackward0>)
# loss 360 tensor(5.7311, grad_fn=<SumBackward0>)
# loss 361 tensor(5.7311, grad_fn=<SumBackward0>)
# loss 362 tensor(5.7307, grad_fn=<SumBackward0>)
# loss 363 tensor(5.7308, grad_fn=<SumBackward0>)
# loss 364 tensor(5.7313, grad_fn=<SumBackward0>)
# loss 365 tensor(5.7304, grad_fn=<SumBackward0>)
# loss 366 tensor(5.7305, grad_fn=<SumBackward0>)
# loss 367 tensor(5.7308, grad_fn=<SumBackward0>)
# loss 368 tensor(5.7303, grad_fn=<SumBackward0>)
# loss 369 tensor(5.7302, grad_fn=<SumBackward0>)
# loss 370 tensor(5.7309, grad_fn=<SumBackward0>)
# loss 371 tensor(5.7303, grad_fn=<SumBackward0>)
# loss 372 tensor(5.7308, grad_fn=<SumBackward0>)
# loss 373 tensor(5.7298, grad_fn=<SumBackward0>)
# loss 374 tensor(5.7298, grad_fn=<SumBackward0>)
# loss 375 tensor(5.7306, grad_fn=<SumBackward0>)
# loss 376 tensor(5.7297, grad_fn=<SumBackward0>)
# loss 377 tensor(5.7299, grad_fn=<SumBackward0>)
# loss 378 tensor(5.7296, grad_fn=<SumBackward0>)
# loss 379 tensor(5.7298, grad_fn=<SumBackward0>)
# loss 380 tensor(5.7296, grad_fn=<SumBackward0>)
# loss 381 tensor(5.7283, grad_fn=<SumBackward0>)
# loss 382 tensor(5.7274, grad_fn=<SumBackward0>)
# loss 383 tensor(5.7279, grad_fn=<SumBackward0>)
# loss 384 tensor(5.7268, grad_fn=<SumBackward0>)
# loss 385 tensor(5.7259, grad_fn=<SumBackward0>)
# loss 386 tensor(5.7261, grad_fn=<SumBackward0>)
# loss 387 tensor(5.7235, grad_fn=<SumBackward0>)
# loss 388 tensor(5.7225, grad_fn=<SumBackward0>)
# loss 389 tensor(5.7215, grad_fn=<SumBackward0>)
# loss 390 tensor(5.7178, grad_fn=<SumBackward0>)
# loss 391 tensor(5.7155, grad_fn=<SumBackward0>)
# loss 392 tensor(5.7114, grad_fn=<SumBackward0>)
# loss 393 tensor(5.7072, grad_fn=<SumBackward0>)
# loss 394 tensor(5.7036, grad_fn=<SumBackward0>)
# loss 395 tensor(5.6987, grad_fn=<SumBackward0>)
# loss 396 tensor(5.6947, grad_fn=<SumBackward0>)
# loss 397 tensor(5.6931, grad_fn=<SumBackward0>)
# loss 398 tensor(5.6895, grad_fn=<SumBackward0>)
# loss 399 tensor(5.6861, grad_fn=<SumBackward0>)

# %%
plt.figure(figsize=(20, 6))
plt.plot(loss_hist)
plt.grid(True)
plt.show()

# %%
gumbel_matrix = weight_feature.detach().max(dim=1)[1]
labels_pred = gumbel_matrix.data.numpy()

# %%
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
plt.axis('off')
#nx.draw(G, pos=pos, node_size=200, node_color=color, with_labels=True)
nx.draw_networkx(G, pos=pos,node_color = "y", node_size=300, with_labels=True)
options = {
    'node_color': 'red',
    'node_size': 50,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.show()
print('Modularity for Train Bombing dataset is %.5f' %mod_calc(G,'Train',labels_pred))

color = []
for c in range(len(gumbel_matrix)):
    if(gumbel_matrix[c] == 0):
        color.append('r')
    elif(gumbel_matrix[c] == 1):
        color.append('g')
    elif(gumbel_matrix[c] == 2):
        color.append('teal')
    elif(gumbel_matrix[c] == 3):
        color.append('greenyellow')
    elif(gumbel_matrix[c] == 4):
        color.append('pink')
    elif(gumbel_matrix[c] == 5):
        color.append('dimgrey')
    elif(gumbel_matrix[c] == 6):
        color.append('peachpuff')
    elif(gumbel_matrix[c] == 7):
        color.append('gold')
    elif(gumbel_matrix[c] == 8):
        color.append('m')
    elif(gumbel_matrix[c] == 9):
        color.append('aqua')
    elif(gumbel_matrix[c] == 10):
        color.append('indianred')
    elif(gumbel_matrix[c] == 11):
        color.append('sienna')
plt.figure(figsize=(10, 10))
plt.axis('off')
options = {
    'node_color': color,
    'node_size': 50,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
#nx.draw(G, **options)
nx.draw_networkx(G, pos=pos, node_size=350, node_color=color, with_labels=True)
plt.show()
# Out:
# Modularity for Train Bombing dataset is 0.43823
