# %%
import pandas as pd 
from sklearn import preprocessing 
data = pd.read_csv("../datasets/windsurfers.csv") 
import networkx as nx
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import math
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from modularity_maximization import partition
from modularity_maximization.utils import get_modularity
from modutils import mod_calc
device = torch.device('cpu')

# %%
G = nx.Graph()
G.add_edges_from(data.values)

comm_dict = partition(G)
clusters_number = len(np.array(list(set(comm_dict.values()))))

# %%
A_hat = nx.adjacency_matrix(G).todense()
X = np.identity(G.number_of_nodes(), dtype=np.float)

# %%
class CDCGS(nn.Module):
    def __init__(self, A_hat, num_feat, num_hidden):
        super(CDCGS, self).__init__()
        self.num_feat = num_feat
        self.num_hidden = num_hidden
        self.A_hat = A_hat
        self.W_0 = nn.Parameter(torch.ones(num_feat, num_hidden))
        I = F.one_hot(torch.tensor(random.sample(range(0, num_feat), num_feat)), num_classes=num_feat)
        self.I = torch.tensor(I,dtype=torch.float)

    def forward(self, X, A_hat,temp):
        global featureSelector
        global weight_feature
        featureSelector = self.W_0
        results = torch.zeros(self.W_0.size())
        x = 500
        for i in range(x):
            results += F.gumbel_softmax(self.W_0,tau=temp,hard=False)
        weight_feature = results/x

        H = torch.mm(torch.mm(self.I,A_hat),self.I.T)
        H = torch.mm(torch.mm(weight_feature.T,A_hat),weight_feature)
        H = torch.div(H, H.sum(axis=0))
        m = nn.Softmax(dim=0)
        return m(H)

num_feat = len(G.nodes())
num_hidden = clusters_number

model = CDCGS(A_hat, num_feat, num_hidden).to(device)

def lossFn(output,exp): 
    return torch.sum((torch.diag(-torch.log(output))))

optimizer = optim.Adam(model.parameters(),lr=1e-2,weight_decay=0,betas=(0.5, 0.999), eps=1e-08)


A_hat_tensor = torch.Tensor(A_hat).to(device)
X_tensor = torch.Tensor(X).to(device)

loss_hist = []
acc_hist = []
temp = 3

for epoch in range(500):
    model.train()
    model.zero_grad()
    if(epoch == 75):
        temp = 2.75
    elif(epoch == 100):
        temp = 2.5
    elif(epoch == 125):
        temp = 2
    elif(epoch == 150):
        temp = 1.8
    elif(epoch == 175):
        temp = 1.25
    elif(epoch == 250):
        temp = 1.00
    elif(epoch == 300):
        temp = 0.75
    elif(epoch == 320):
        temp = 0.5
    output = model(X_tensor, A_hat_tensor,temp)
    loss = lossFn(output,torch.diag(torch.ones(output.size()[0])))
    loss_hist.append(loss.item())
    print('loss',epoch,loss)
    loss.backward()
    optimizer.step()
# Out:
# /opt/anaconda/envs/Deepak/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':
# loss 0 tensor(1.3863, grad_fn=<SumBackward0>)
# loss 1 tensor(1.3863, grad_fn=<SumBackward0>)
# loss 2 tensor(1.3863, grad_fn=<SumBackward0>)
# loss 3 tensor(1.3863, grad_fn=<SumBackward0>)
# loss 4 tensor(1.3863, grad_fn=<SumBackward0>)
# loss 5 tensor(1.3862, grad_fn=<SumBackward0>)
# loss 6 tensor(1.3861, grad_fn=<SumBackward0>)
# loss 7 tensor(1.3861, grad_fn=<SumBackward0>)
# loss 8 tensor(1.3860, grad_fn=<SumBackward0>)
# loss 9 tensor(1.3859, grad_fn=<SumBackward0>)
# loss 10 tensor(1.3857, grad_fn=<SumBackward0>)
# loss 11 tensor(1.3857, grad_fn=<SumBackward0>)
# loss 12 tensor(1.3854, grad_fn=<SumBackward0>)
# loss 13 tensor(1.3852, grad_fn=<SumBackward0>)
# loss 14 tensor(1.3849, grad_fn=<SumBackward0>)
# loss 15 tensor(1.3847, grad_fn=<SumBackward0>)
# loss 16 tensor(1.3846, grad_fn=<SumBackward0>)
# loss 17 tensor(1.3837, grad_fn=<SumBackward0>)
# loss 18 tensor(1.3838, grad_fn=<SumBackward0>)
# loss 19 tensor(1.3831, grad_fn=<SumBackward0>)
# loss 20 tensor(1.3827, grad_fn=<SumBackward0>)
# loss 21 tensor(1.3822, grad_fn=<SumBackward0>)
# loss 22 tensor(1.3818, grad_fn=<SumBackward0>)
# loss 23 tensor(1.3813, grad_fn=<SumBackward0>)
# loss 24 tensor(1.3808, grad_fn=<SumBackward0>)
# loss 25 tensor(1.3799, grad_fn=<SumBackward0>)
# loss 26 tensor(1.3796, grad_fn=<SumBackward0>)
# loss 27 tensor(1.3785, grad_fn=<SumBackward0>)
# loss 28 tensor(1.3781, grad_fn=<SumBackward0>)
# loss 29 tensor(1.3775, grad_fn=<SumBackward0>)
# loss 30 tensor(1.3770, grad_fn=<SumBackward0>)
# loss 31 tensor(1.3763, grad_fn=<SumBackward0>)
# loss 32 tensor(1.3749, grad_fn=<SumBackward0>)
# loss 33 tensor(1.3745, grad_fn=<SumBackward0>)
# loss 34 tensor(1.3737, grad_fn=<SumBackward0>)
# loss 35 tensor(1.3724, grad_fn=<SumBackward0>)
# loss 36 tensor(1.3721, grad_fn=<SumBackward0>)
# loss 37 tensor(1.3710, grad_fn=<SumBackward0>)
# loss 38 tensor(1.3697, grad_fn=<SumBackward0>)
# loss 39 tensor(1.3691, grad_fn=<SumBackward0>)
# loss 40 tensor(1.3677, grad_fn=<SumBackward0>)
# loss 41 tensor(1.3663, grad_fn=<SumBackward0>)
# loss 42 tensor(1.3662, grad_fn=<SumBackward0>)
# loss 43 tensor(1.3641, grad_fn=<SumBackward0>)
# loss 44 tensor(1.3638, grad_fn=<SumBackward0>)
# loss 45 tensor(1.3630, grad_fn=<SumBackward0>)
# loss 46 tensor(1.3617, grad_fn=<SumBackward0>)
# loss 47 tensor(1.3616, grad_fn=<SumBackward0>)
# loss 48 tensor(1.3595, grad_fn=<SumBackward0>)
# loss 49 tensor(1.3587, grad_fn=<SumBackward0>)
# loss 50 tensor(1.3576, grad_fn=<SumBackward0>)
# loss 51 tensor(1.3557, grad_fn=<SumBackward0>)
# loss 52 tensor(1.3538, grad_fn=<SumBackward0>)
# loss 53 tensor(1.3532, grad_fn=<SumBackward0>)
# loss 54 tensor(1.3520, grad_fn=<SumBackward0>)
# loss 55 tensor(1.3511, grad_fn=<SumBackward0>)
# loss 56 tensor(1.3500, grad_fn=<SumBackward0>)
# loss 57 tensor(1.3485, grad_fn=<SumBackward0>)
# loss 58 tensor(1.3479, grad_fn=<SumBackward0>)
# loss 59 tensor(1.3456, grad_fn=<SumBackward0>)
# loss 60 tensor(1.3434, grad_fn=<SumBackward0>)
# loss 61 tensor(1.3432, grad_fn=<SumBackward0>)
# loss 62 tensor(1.3410, grad_fn=<SumBackward0>)
# loss 63 tensor(1.3397, grad_fn=<SumBackward0>)
# loss 64 tensor(1.3390, grad_fn=<SumBackward0>)
# loss 65 tensor(1.3368, grad_fn=<SumBackward0>)
# loss 66 tensor(1.3358, grad_fn=<SumBackward0>)
# loss 67 tensor(1.3338, grad_fn=<SumBackward0>)
# loss 68 tensor(1.3332, grad_fn=<SumBackward0>)
# loss 69 tensor(1.3312, grad_fn=<SumBackward0>)
# loss 70 tensor(1.3312, grad_fn=<SumBackward0>)
# loss 71 tensor(1.3283, grad_fn=<SumBackward0>)
# loss 72 tensor(1.3274, grad_fn=<SumBackward0>)
# loss 73 tensor(1.3250, grad_fn=<SumBackward0>)
# loss 74 tensor(1.3245, grad_fn=<SumBackward0>)
# loss 75 tensor(1.3136, grad_fn=<SumBackward0>)
# loss 76 tensor(1.3112, grad_fn=<SumBackward0>)
# loss 77 tensor(1.3097, grad_fn=<SumBackward0>)
# loss 78 tensor(1.3079, grad_fn=<SumBackward0>)
# loss 79 tensor(1.3063, grad_fn=<SumBackward0>)
# loss 80 tensor(1.3054, grad_fn=<SumBackward0>)
# loss 81 tensor(1.3011, grad_fn=<SumBackward0>)
# loss 82 tensor(1.3004, grad_fn=<SumBackward0>)
# loss 83 tensor(1.2966, grad_fn=<SumBackward0>)
# loss 84 tensor(1.2940, grad_fn=<SumBackward0>)
# loss 85 tensor(1.2935, grad_fn=<SumBackward0>)
# loss 86 tensor(1.2922, grad_fn=<SumBackward0>)
# loss 87 tensor(1.2905, grad_fn=<SumBackward0>)
# loss 88 tensor(1.2882, grad_fn=<SumBackward0>)
# loss 89 tensor(1.2857, grad_fn=<SumBackward0>)
# loss 90 tensor(1.2846, grad_fn=<SumBackward0>)
# loss 91 tensor(1.2826, grad_fn=<SumBackward0>)
# loss 92 tensor(1.2810, grad_fn=<SumBackward0>)
# loss 93 tensor(1.2786, grad_fn=<SumBackward0>)
# loss 94 tensor(1.2758, grad_fn=<SumBackward0>)
# loss 95 tensor(1.2752, grad_fn=<SumBackward0>)
# loss 96 tensor(1.2722, grad_fn=<SumBackward0>)
# loss 97 tensor(1.2709, grad_fn=<SumBackward0>)
# loss 98 tensor(1.2679, grad_fn=<SumBackward0>)
# loss 99 tensor(1.2667, grad_fn=<SumBackward0>)
# loss 100 tensor(1.2502, grad_fn=<SumBackward0>)
# loss 101 tensor(1.2460, grad_fn=<SumBackward0>)
# loss 102 tensor(1.2461, grad_fn=<SumBackward0>)
# loss 103 tensor(1.2425, grad_fn=<SumBackward0>)
# loss 104 tensor(1.2400, grad_fn=<SumBackward0>)
# loss 105 tensor(1.2380, grad_fn=<SumBackward0>)
# loss 106 tensor(1.2354, grad_fn=<SumBackward0>)
# loss 107 tensor(1.2319, grad_fn=<SumBackward0>)
# loss 108 tensor(1.2313, grad_fn=<SumBackward0>)
# loss 109 tensor(1.2294, grad_fn=<SumBackward0>)
# loss 110 tensor(1.2265, grad_fn=<SumBackward0>)
# loss 111 tensor(1.2253, grad_fn=<SumBackward0>)
# loss 112 tensor(1.2224, grad_fn=<SumBackward0>)
# loss 113 tensor(1.2214, grad_fn=<SumBackward0>)
# loss 114 tensor(1.2190, grad_fn=<SumBackward0>)
# loss 115 tensor(1.2180, grad_fn=<SumBackward0>)
# loss 116 tensor(1.2136, grad_fn=<SumBackward0>)
# loss 117 tensor(1.2127, grad_fn=<SumBackward0>)
# loss 118 tensor(1.2118, grad_fn=<SumBackward0>)
# loss 119 tensor(1.2072, grad_fn=<SumBackward0>)
# loss 120 tensor(1.2069, grad_fn=<SumBackward0>)
# loss 121 tensor(1.2065, grad_fn=<SumBackward0>)
# loss 122 tensor(1.2024, grad_fn=<SumBackward0>)
# loss 123 tensor(1.2011, grad_fn=<SumBackward0>)
# loss 124 tensor(1.1970, grad_fn=<SumBackward0>)
# loss 125 tensor(1.1467, grad_fn=<SumBackward0>)
# loss 126 tensor(1.1428, grad_fn=<SumBackward0>)
# loss 127 tensor(1.1422, grad_fn=<SumBackward0>)
# loss 128 tensor(1.1381, grad_fn=<SumBackward0>)
# loss 129 tensor(1.1374, grad_fn=<SumBackward0>)
# loss 130 tensor(1.1360, grad_fn=<SumBackward0>)
# loss 131 tensor(1.1334, grad_fn=<SumBackward0>)
# loss 132 tensor(1.1318, grad_fn=<SumBackward0>)
# loss 133 tensor(1.1301, grad_fn=<SumBackward0>)
# loss 134 tensor(1.1277, grad_fn=<SumBackward0>)
# loss 135 tensor(1.1259, grad_fn=<SumBackward0>)
# loss 136 tensor(1.1225, grad_fn=<SumBackward0>)
# loss 137 tensor(1.1217, grad_fn=<SumBackward0>)
# loss 138 tensor(1.1221, grad_fn=<SumBackward0>)
# loss 139 tensor(1.1181, grad_fn=<SumBackward0>)
# loss 140 tensor(1.1180, grad_fn=<SumBackward0>)
# loss 141 tensor(1.1138, grad_fn=<SumBackward0>)
# loss 142 tensor(1.1135, grad_fn=<SumBackward0>)
# loss 143 tensor(1.1109, grad_fn=<SumBackward0>)
# loss 144 tensor(1.1072, grad_fn=<SumBackward0>)
# loss 145 tensor(1.1057, grad_fn=<SumBackward0>)
# loss 146 tensor(1.1077, grad_fn=<SumBackward0>)
# loss 147 tensor(1.1038, grad_fn=<SumBackward0>)
# loss 148 tensor(1.1008, grad_fn=<SumBackward0>)
# loss 149 tensor(1.1016, grad_fn=<SumBackward0>)
# loss 150 tensor(1.0748, grad_fn=<SumBackward0>)
# loss 151 tensor(1.0730, grad_fn=<SumBackward0>)
# loss 152 tensor(1.0739, grad_fn=<SumBackward0>)
# loss 153 tensor(1.0721, grad_fn=<SumBackward0>)
# loss 154 tensor(1.0700, grad_fn=<SumBackward0>)
# loss 155 tensor(1.0700, grad_fn=<SumBackward0>)
# loss 156 tensor(1.0673, grad_fn=<SumBackward0>)
# loss 157 tensor(1.0648, grad_fn=<SumBackward0>)
# loss 158 tensor(1.0645, grad_fn=<SumBackward0>)
# loss 159 tensor(1.0629, grad_fn=<SumBackward0>)
# loss 160 tensor(1.0625, grad_fn=<SumBackward0>)
# loss 161 tensor(1.0603, grad_fn=<SumBackward0>)
# loss 162 tensor(1.0598, grad_fn=<SumBackward0>)
# loss 163 tensor(1.0587, grad_fn=<SumBackward0>)
# loss 164 tensor(1.0551, grad_fn=<SumBackward0>)
# loss 165 tensor(1.0561, grad_fn=<SumBackward0>)
# loss 166 tensor(1.0559, grad_fn=<SumBackward0>)
# loss 167 tensor(1.0529, grad_fn=<SumBackward0>)
# loss 168 tensor(1.0546, grad_fn=<SumBackward0>)
# loss 169 tensor(1.0526, grad_fn=<SumBackward0>)
# loss 170 tensor(1.0487, grad_fn=<SumBackward0>)
# loss 171 tensor(1.0489, grad_fn=<SumBackward0>)
# loss 172 tensor(1.0490, grad_fn=<SumBackward0>)
# loss 173 tensor(1.0485, grad_fn=<SumBackward0>)
# loss 174 tensor(1.0469, grad_fn=<SumBackward0>)
# loss 175 tensor(0.9884, grad_fn=<SumBackward0>)
# loss 176 tensor(0.9863, grad_fn=<SumBackward0>)
# loss 177 tensor(0.9867, grad_fn=<SumBackward0>)
# loss 178 tensor(0.9852, grad_fn=<SumBackward0>)
# loss 179 tensor(0.9848, grad_fn=<SumBackward0>)
# loss 180 tensor(0.9836, grad_fn=<SumBackward0>)
# loss 181 tensor(0.9839, grad_fn=<SumBackward0>)
# loss 182 tensor(0.9823, grad_fn=<SumBackward0>)
# loss 183 tensor(0.9839, grad_fn=<SumBackward0>)
# loss 184 tensor(0.9825, grad_fn=<SumBackward0>)
# loss 185 tensor(0.9823, grad_fn=<SumBackward0>)
# loss 186 tensor(0.9814, grad_fn=<SumBackward0>)
# loss 187 tensor(0.9799, grad_fn=<SumBackward0>)
# loss 188 tensor(0.9806, grad_fn=<SumBackward0>)
# loss 189 tensor(0.9817, grad_fn=<SumBackward0>)
# loss 190 tensor(0.9801, grad_fn=<SumBackward0>)
# loss 191 tensor(0.9792, grad_fn=<SumBackward0>)
# loss 192 tensor(0.9801, grad_fn=<SumBackward0>)
# loss 193 tensor(0.9792, grad_fn=<SumBackward0>)
# loss 194 tensor(0.9781, grad_fn=<SumBackward0>)
# loss 195 tensor(0.9770, grad_fn=<SumBackward0>)
# loss 196 tensor(0.9789, grad_fn=<SumBackward0>)
# loss 197 tensor(0.9787, grad_fn=<SumBackward0>)
# loss 198 tensor(0.9785, grad_fn=<SumBackward0>)
# loss 199 tensor(0.9765, grad_fn=<SumBackward0>)
# loss 200 tensor(0.9773, grad_fn=<SumBackward0>)
# loss 201 tensor(0.9753, grad_fn=<SumBackward0>)
# loss 202 tensor(0.9769, grad_fn=<SumBackward0>)
# loss 203 tensor(0.9745, grad_fn=<SumBackward0>)
# loss 204 tensor(0.9753, grad_fn=<SumBackward0>)
# loss 205 tensor(0.9747, grad_fn=<SumBackward0>)
# loss 206 tensor(0.9745, grad_fn=<SumBackward0>)
# loss 207 tensor(0.9748, grad_fn=<SumBackward0>)
# loss 208 tensor(0.9732, grad_fn=<SumBackward0>)
# loss 209 tensor(0.9727, grad_fn=<SumBackward0>)
# loss 210 tensor(0.9733, grad_fn=<SumBackward0>)
# loss 211 tensor(0.9718, grad_fn=<SumBackward0>)
# loss 212 tensor(0.9733, grad_fn=<SumBackward0>)
# loss 213 tensor(0.9715, grad_fn=<SumBackward0>)
# loss 214 tensor(0.9710, grad_fn=<SumBackward0>)
# loss 215 tensor(0.9704, grad_fn=<SumBackward0>)
# loss 216 tensor(0.9719, grad_fn=<SumBackward0>)
# loss 217 tensor(0.9709, grad_fn=<SumBackward0>)
# loss 218 tensor(0.9709, grad_fn=<SumBackward0>)
# loss 219 tensor(0.9695, grad_fn=<SumBackward0>)
# loss 220 tensor(0.9692, grad_fn=<SumBackward0>)
# loss 221 tensor(0.9698, grad_fn=<SumBackward0>)
# loss 222 tensor(0.9698, grad_fn=<SumBackward0>)
# loss 223 tensor(0.9693, grad_fn=<SumBackward0>)
# loss 224 tensor(0.9686, grad_fn=<SumBackward0>)
# loss 225 tensor(0.9685, grad_fn=<SumBackward0>)
# loss 226 tensor(0.9676, grad_fn=<SumBackward0>)
# loss 227 tensor(0.9676, grad_fn=<SumBackward0>)
# loss 228 tensor(0.9682, grad_fn=<SumBackward0>)
# loss 229 tensor(0.9672, grad_fn=<SumBackward0>)
# loss 230 tensor(0.9667, grad_fn=<SumBackward0>)
# loss 231 tensor(0.9675, grad_fn=<SumBackward0>)
# loss 232 tensor(0.9667, grad_fn=<SumBackward0>)
# loss 233 tensor(0.9660, grad_fn=<SumBackward0>)
# loss 234 tensor(0.9668, grad_fn=<SumBackward0>)
# loss 235 tensor(0.9657, grad_fn=<SumBackward0>)
# loss 236 tensor(0.9654, grad_fn=<SumBackward0>)
# loss 237 tensor(0.9659, grad_fn=<SumBackward0>)
# loss 238 tensor(0.9663, grad_fn=<SumBackward0>)
# loss 239 tensor(0.9662, grad_fn=<SumBackward0>)
# loss 240 tensor(0.9648, grad_fn=<SumBackward0>)
# loss 241 tensor(0.9647, grad_fn=<SumBackward0>)
# loss 242 tensor(0.9654, grad_fn=<SumBackward0>)
# loss 243 tensor(0.9645, grad_fn=<SumBackward0>)
# loss 244 tensor(0.9637, grad_fn=<SumBackward0>)
# loss 245 tensor(0.9642, grad_fn=<SumBackward0>)
# loss 246 tensor(0.9632, grad_fn=<SumBackward0>)
# loss 247 tensor(0.9634, grad_fn=<SumBackward0>)
# loss 248 tensor(0.9631, grad_fn=<SumBackward0>)
# loss 249 tensor(0.9625, grad_fn=<SumBackward0>)
# loss 250 tensor(0.9496, grad_fn=<SumBackward0>)
# loss 251 tensor(0.9485, grad_fn=<SumBackward0>)
# loss 252 tensor(0.9488, grad_fn=<SumBackward0>)
# loss 253 tensor(0.9491, grad_fn=<SumBackward0>)
# loss 254 tensor(0.9484, grad_fn=<SumBackward0>)
# loss 255 tensor(0.9484, grad_fn=<SumBackward0>)
# loss 256 tensor(0.9491, grad_fn=<SumBackward0>)
# loss 257 tensor(0.9477, grad_fn=<SumBackward0>)
# loss 258 tensor(0.9483, grad_fn=<SumBackward0>)
# loss 259 tensor(0.9485, grad_fn=<SumBackward0>)
# loss 260 tensor(0.9479, grad_fn=<SumBackward0>)
# loss 261 tensor(0.9478, grad_fn=<SumBackward0>)
# loss 262 tensor(0.9481, grad_fn=<SumBackward0>)
# loss 263 tensor(0.9486, grad_fn=<SumBackward0>)
# loss 264 tensor(0.9480, grad_fn=<SumBackward0>)
# loss 265 tensor(0.9482, grad_fn=<SumBackward0>)
# loss 266 tensor(0.9484, grad_fn=<SumBackward0>)
# loss 267 tensor(0.9465, grad_fn=<SumBackward0>)
# loss 268 tensor(0.9478, grad_fn=<SumBackward0>)
# loss 269 tensor(0.9475, grad_fn=<SumBackward0>)
# loss 270 tensor(0.9470, grad_fn=<SumBackward0>)
# loss 271 tensor(0.9466, grad_fn=<SumBackward0>)
# loss 272 tensor(0.9475, grad_fn=<SumBackward0>)
# loss 273 tensor(0.9476, grad_fn=<SumBackward0>)
# loss 274 tensor(0.9470, grad_fn=<SumBackward0>)
# loss 275 tensor(0.9463, grad_fn=<SumBackward0>)
# loss 276 tensor(0.9474, grad_fn=<SumBackward0>)
# loss 277 tensor(0.9474, grad_fn=<SumBackward0>)
# loss 278 tensor(0.9465, grad_fn=<SumBackward0>)
# loss 279 tensor(0.9466, grad_fn=<SumBackward0>)
# loss 280 tensor(0.9464, grad_fn=<SumBackward0>)
# loss 281 tensor(0.9469, grad_fn=<SumBackward0>)
# loss 282 tensor(0.9467, grad_fn=<SumBackward0>)
# loss 283 tensor(0.9461, grad_fn=<SumBackward0>)
# loss 284 tensor(0.9462, grad_fn=<SumBackward0>)
# loss 285 tensor(0.9471, grad_fn=<SumBackward0>)
# loss 286 tensor(0.9458, grad_fn=<SumBackward0>)
# loss 287 tensor(0.9459, grad_fn=<SumBackward0>)
# loss 288 tensor(0.9467, grad_fn=<SumBackward0>)
# loss 289 tensor(0.9458, grad_fn=<SumBackward0>)
# loss 290 tensor(0.9462, grad_fn=<SumBackward0>)
# loss 291 tensor(0.9456, grad_fn=<SumBackward0>)
# loss 292 tensor(0.9451, grad_fn=<SumBackward0>)
# loss 293 tensor(0.9455, grad_fn=<SumBackward0>)
# loss 294 tensor(0.9451, grad_fn=<SumBackward0>)
# loss 295 tensor(0.9448, grad_fn=<SumBackward0>)
# loss 296 tensor(0.9450, grad_fn=<SumBackward0>)
# loss 297 tensor(0.9450, grad_fn=<SumBackward0>)
# loss 298 tensor(0.9448, grad_fn=<SumBackward0>)
# loss 299 tensor(0.9453, grad_fn=<SumBackward0>)
# loss 300 tensor(0.9390, grad_fn=<SumBackward0>)
# loss 301 tensor(0.9392, grad_fn=<SumBackward0>)
# loss 302 tensor(0.9387, grad_fn=<SumBackward0>)
# loss 303 tensor(0.9393, grad_fn=<SumBackward0>)
# loss 304 tensor(0.9386, grad_fn=<SumBackward0>)
# loss 305 tensor(0.9382, grad_fn=<SumBackward0>)
# loss 306 tensor(0.9387, grad_fn=<SumBackward0>)
# loss 307 tensor(0.9385, grad_fn=<SumBackward0>)
# loss 308 tensor(0.9379, grad_fn=<SumBackward0>)
# loss 309 tensor(0.9383, grad_fn=<SumBackward0>)
# loss 310 tensor(0.9375, grad_fn=<SumBackward0>)
# loss 311 tensor(0.9382, grad_fn=<SumBackward0>)
# loss 312 tensor(0.9383, grad_fn=<SumBackward0>)
# loss 313 tensor(0.9381, grad_fn=<SumBackward0>)
# loss 314 tensor(0.9375, grad_fn=<SumBackward0>)
# loss 315 tensor(0.9382, grad_fn=<SumBackward0>)
# loss 316 tensor(0.9379, grad_fn=<SumBackward0>)
# loss 317 tensor(0.9392, grad_fn=<SumBackward0>)
# loss 318 tensor(0.9388, grad_fn=<SumBackward0>)
# loss 319 tensor(0.9383, grad_fn=<SumBackward0>)
# loss 320 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 321 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 322 tensor(0.9352, grad_fn=<SumBackward0>)
# loss 323 tensor(0.9356, grad_fn=<SumBackward0>)
# loss 324 tensor(0.9351, grad_fn=<SumBackward0>)
# loss 325 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 326 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 327 tensor(0.9359, grad_fn=<SumBackward0>)
# loss 328 tensor(0.9347, grad_fn=<SumBackward0>)
# loss 329 tensor(0.9359, grad_fn=<SumBackward0>)
# loss 330 tensor(0.9355, grad_fn=<SumBackward0>)
# loss 331 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 332 tensor(0.9356, grad_fn=<SumBackward0>)
# loss 333 tensor(0.9356, grad_fn=<SumBackward0>)
# loss 334 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 335 tensor(0.9351, grad_fn=<SumBackward0>)
# loss 336 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 337 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 338 tensor(0.9351, grad_fn=<SumBackward0>)
# loss 339 tensor(0.9355, grad_fn=<SumBackward0>)
# loss 340 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 341 tensor(0.9355, grad_fn=<SumBackward0>)
# loss 342 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 343 tensor(0.9347, grad_fn=<SumBackward0>)
# loss 344 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 345 tensor(0.9355, grad_fn=<SumBackward0>)
# loss 346 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 347 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 348 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 349 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 350 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 351 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 352 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 353 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 354 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 355 tensor(0.9362, grad_fn=<SumBackward0>)
# loss 356 tensor(0.9352, grad_fn=<SumBackward0>)
# loss 357 tensor(0.9356, grad_fn=<SumBackward0>)
# loss 358 tensor(0.9353, grad_fn=<SumBackward0>)
# loss 359 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 360 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 361 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 362 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 363 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 364 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 365 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 366 tensor(0.9352, grad_fn=<SumBackward0>)
# loss 367 tensor(0.9351, grad_fn=<SumBackward0>)
# loss 368 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 369 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 370 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 371 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 372 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 373 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 374 tensor(0.9352, grad_fn=<SumBackward0>)
# loss 375 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 376 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 377 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 378 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 379 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 380 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 381 tensor(0.9355, grad_fn=<SumBackward0>)
# loss 382 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 383 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 384 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 385 tensor(0.9340, grad_fn=<SumBackward0>)
# loss 386 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 387 tensor(0.9354, grad_fn=<SumBackward0>)
# loss 388 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 389 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 390 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 391 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 392 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 393 tensor(0.9353, grad_fn=<SumBackward0>)
# loss 394 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 395 tensor(0.9351, grad_fn=<SumBackward0>)
# loss 396 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 397 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 398 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 399 tensor(0.9354, grad_fn=<SumBackward0>)
# loss 400 tensor(0.9340, grad_fn=<SumBackward0>)
# loss 401 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 402 tensor(0.9351, grad_fn=<SumBackward0>)
# loss 403 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 404 tensor(0.9357, grad_fn=<SumBackward0>)
# loss 405 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 406 tensor(0.9337, grad_fn=<SumBackward0>)
# loss 407 tensor(0.9350, grad_fn=<SumBackward0>)
# loss 408 tensor(0.9352, grad_fn=<SumBackward0>)
# loss 409 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 410 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 411 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 412 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 413 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 414 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 415 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 416 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 417 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 418 tensor(0.9347, grad_fn=<SumBackward0>)
# loss 419 tensor(0.9347, grad_fn=<SumBackward0>)
# loss 420 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 421 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 422 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 423 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 424 tensor(0.9353, grad_fn=<SumBackward0>)
# loss 425 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 426 tensor(0.9347, grad_fn=<SumBackward0>)
# loss 427 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 428 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 429 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 430 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 431 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 432 tensor(0.9352, grad_fn=<SumBackward0>)
# loss 433 tensor(0.9351, grad_fn=<SumBackward0>)
# loss 434 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 435 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 436 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 437 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 438 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 439 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 440 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 441 tensor(0.9349, grad_fn=<SumBackward0>)
# loss 442 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 443 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 444 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 445 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 446 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 447 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 448 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 449 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 450 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 451 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 452 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 453 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 454 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 455 tensor(0.9347, grad_fn=<SumBackward0>)
# loss 456 tensor(0.9335, grad_fn=<SumBackward0>)
# loss 457 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 458 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 459 tensor(0.9340, grad_fn=<SumBackward0>)
# loss 460 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 461 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 462 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 463 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 464 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 465 tensor(0.9346, grad_fn=<SumBackward0>)
# loss 466 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 467 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 468 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 469 tensor(0.9348, grad_fn=<SumBackward0>)
# loss 470 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 471 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 472 tensor(0.9342, grad_fn=<SumBackward0>)
# loss 473 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 474 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 475 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 476 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 477 tensor(0.9337, grad_fn=<SumBackward0>)
# loss 478 tensor(0.9344, grad_fn=<SumBackward0>)
# loss 479 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 480 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 481 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 482 tensor(0.9340, grad_fn=<SumBackward0>)
# loss 483 tensor(0.9336, grad_fn=<SumBackward0>)
# loss 484 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 485 tensor(0.9341, grad_fn=<SumBackward0>)
# loss 486 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 487 tensor(0.9337, grad_fn=<SumBackward0>)
# loss 488 tensor(0.9336, grad_fn=<SumBackward0>)
# loss 489 tensor(0.9340, grad_fn=<SumBackward0>)
# loss 490 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 491 tensor(0.9340, grad_fn=<SumBackward0>)
# loss 492 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 493 tensor(0.9345, grad_fn=<SumBackward0>)
# loss 494 tensor(0.9337, grad_fn=<SumBackward0>)
# loss 495 tensor(0.9340, grad_fn=<SumBackward0>)
# loss 496 tensor(0.9339, grad_fn=<SumBackward0>)
# loss 497 tensor(0.9343, grad_fn=<SumBackward0>)
# loss 498 tensor(0.9338, grad_fn=<SumBackward0>)
# loss 499 tensor(0.9340, grad_fn=<SumBackward0>)

# %%
plt.figure(figsize=(20, 6))
plt.plot(loss_hist)
plt.grid(True)
plt.show()

# %%
gumbel_matrix = weight_feature.detach().max(dim=1)[1]
labels_pred = gumbel_matrix.data.numpy()

# %%
pos = nx.spring_layout(G)
plt.figure(figsize=(12, 12))
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=300, with_labels=True)
options = {
    'node_color': 'red',
    'node_size': 50,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.show()
print('Modularity for Windsurfers dataset is %.5f' %mod_calc(G,'Windsurfers',labels_pred))

color = []
for c in range(len(gumbel_matrix)):
    if(gumbel_matrix[c] == 0):
        color.append('r')
    elif(gumbel_matrix[c] == 1):
        color.append('g')
    elif(gumbel_matrix[c] == 2):
        color.append('teal')
    elif(gumbel_matrix[c] == 3):
        color.append('greenyellow')
plt.figure(figsize=(12, 12))
options = {
    'node_color': color,
    'node_size': 50,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
#nx.draw(G, **options)
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=350, node_color=color, with_labels=True)
plt.show()
# Out:
# /opt/anaconda/envs/Deepak/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# Modularity for Windsurfers dataset is 0.25814

# %%
import networkx as nx
from karateclub import MNMF,DANMF,EdMot,GEMSEC,SCD

model3 = EdMot()
model3.fit(G)
cluster_membership3 = model3.get_memberships()
clusters3 = cluster_membership3
labels_pred3 = list(clusters3.values())

print('Modularity of such partition for EdMot is %.6f' %get_modularity(G, labels_pred3))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for EdMot is 0.137538

# %%
model4 = GEMSEC(clusters=clusters_number)
model4.fit(G)
cluster_membership4 = model4.get_memberships()
clusters4 = cluster_membership4
labels_pred4 = list(clusters4.values())
print('Modularity of such partition for GEMSEC is %.6f' %get_modularity(G, labels_pred4))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for GEMSEC is 0.254517

# %%
model5 = SCD()
model5.fit(G)
cluster_membership5 = model5.get_memberships()
clusters5 = cluster_membership5
labels_pred5 = list(clusters5.values())
print('Modularity of such partition for SCD is %.6f' %get_modularity(G, labels_pred5))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for SCD is 0.151958

# %%
model1 = MNMF(clusters=clusters_number)
model1.fit(G)
cluster_membership1 = model1.get_memberships()
clusters1 = cluster_membership1
labels_pred1 = list(clusters1.values())
print('Modularity of such partition for MNMF is %.6f' %get_modularity(G, labels_pred1))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for MNMF is 0.254517

# %%
model2 = DANMF(layers=[32, clusters_number])
model2.fit(G)
cluster_membership2 = model2.get_memberships()
clusters2 = cluster_membership2
labels_pred2 = list(clusters2.values())
print('Modularity of such partition for DANMF is %.6f' %get_modularity(G, labels_pred2))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for DANMF is 0.246807
