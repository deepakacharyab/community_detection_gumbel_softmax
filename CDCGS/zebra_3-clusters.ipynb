# %%
import pandas as pd 
from sklearn import preprocessing 
data = pd.read_csv("../datasets/zebra.csv") 
import networkx as nx
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import math
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from modularity_maximization import partition
from modularity_maximization.utils import get_modularity
from modutils import mod_calc
device = torch.device('cpu')

# %%
G = nx.Graph()
G.add_edges_from(data.values)

comm_dict = partition(G)
clusters_number = len(np.array(list(set(comm_dict.values()))))

# %%
A_hat = nx.adjacency_matrix(G).todense()
X = np.identity(G.number_of_nodes(), dtype=np.float)

# %%
class CDCGS(nn.Module):
    def __init__(self, A_hat, num_feat, num_hidden):
        super(CDCGS, self).__init__()
        self.num_feat = num_feat
        self.num_hidden = num_hidden
        self.A_hat = A_hat
        self.W_0 = nn.Parameter(torch.ones(num_feat, num_hidden))
        I = F.one_hot(torch.tensor(random.sample(range(0, num_feat), num_feat)), num_classes=num_feat)
        self.I = torch.tensor(I,dtype=torch.float)

    def forward(self, X, A_hat,temp):
        global featureSelector
        global weight_feature
        featureSelector = self.W_0
        results = torch.zeros(self.W_0.size())
        x = 500
        for i in range(x):
            results += F.gumbel_softmax(self.W_0,tau=temp,hard=False)
        weight_feature = results/x

        H = torch.mm(torch.mm(self.I,A_hat),self.I.T)
        H = torch.mm(torch.mm(weight_feature.T,A_hat),weight_feature)
        H = torch.div(H, H.sum(axis=0))
        m = nn.Softmax(dim=0)
        return m(H)

num_feat = len(G.nodes())
num_hidden = clusters_number

model = CDCGS(A_hat, num_feat, num_hidden).to(device)

def lossFn(output,exp): 
    return torch.sum((torch.diag(-torch.log(output))))

optimizer = optim.Adam(model.parameters(),lr=1e-2,weight_decay=0,betas=(0.5, 0.999), eps=1e-08)


A_hat_tensor = torch.Tensor(A_hat).to(device)
X_tensor = torch.Tensor(X).to(device)

loss_hist = []
acc_hist = []
temp = 3

for epoch in range(500):
    model.train()
    model.zero_grad()
    if(epoch == 75):
        temp = 2.75
    elif(epoch == 100):
        temp = 2.5
    elif(epoch == 125):
        temp = 2
    elif(epoch == 150):
        temp = 1.8
    elif(epoch == 175):
        temp = 1.25
    elif(epoch == 250):
        temp = 1.00
    elif(epoch == 300):
        temp = 0.75
    elif(epoch == 320):
        temp = 0.50
    elif(epoch == 400):
        temp = 0.2
    output = model(X_tensor, A_hat_tensor,temp)
    loss = lossFn(output,torch.diag(torch.ones(output.size()[0])))
    loss_hist.append(loss.item())
    print('loss',epoch,loss)
    loss.backward()
    optimizer.step()
# Out:
# /opt/anaconda/envs/Deepak/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':
# loss 0 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 1 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 2 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 3 tensor(3.2959, grad_fn=<SumBackward0>)
# loss 4 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 5 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 6 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 7 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 8 tensor(3.2958, grad_fn=<SumBackward0>)
# loss 9 tensor(3.2957, grad_fn=<SumBackward0>)
# loss 10 tensor(3.2956, grad_fn=<SumBackward0>)
# loss 11 tensor(3.2956, grad_fn=<SumBackward0>)
# loss 12 tensor(3.2955, grad_fn=<SumBackward0>)
# loss 13 tensor(3.2953, grad_fn=<SumBackward0>)
# loss 14 tensor(3.2953, grad_fn=<SumBackward0>)
# loss 15 tensor(3.2950, grad_fn=<SumBackward0>)
# loss 16 tensor(3.2947, grad_fn=<SumBackward0>)
# loss 17 tensor(3.2947, grad_fn=<SumBackward0>)
# loss 18 tensor(3.2942, grad_fn=<SumBackward0>)
# loss 19 tensor(3.2940, grad_fn=<SumBackward0>)
# loss 20 tensor(3.2937, grad_fn=<SumBackward0>)
# loss 21 tensor(3.2934, grad_fn=<SumBackward0>)
# loss 22 tensor(3.2928, grad_fn=<SumBackward0>)
# loss 23 tensor(3.2926, grad_fn=<SumBackward0>)
# loss 24 tensor(3.2923, grad_fn=<SumBackward0>)
# loss 25 tensor(3.2921, grad_fn=<SumBackward0>)
# loss 26 tensor(3.2912, grad_fn=<SumBackward0>)
# loss 27 tensor(3.2908, grad_fn=<SumBackward0>)
# loss 28 tensor(3.2901, grad_fn=<SumBackward0>)
# loss 29 tensor(3.2900, grad_fn=<SumBackward0>)
# loss 30 tensor(3.2894, grad_fn=<SumBackward0>)
# loss 31 tensor(3.2892, grad_fn=<SumBackward0>)
# loss 32 tensor(3.2886, grad_fn=<SumBackward0>)
# loss 33 tensor(3.2877, grad_fn=<SumBackward0>)
# loss 34 tensor(3.2875, grad_fn=<SumBackward0>)
# loss 35 tensor(3.2866, grad_fn=<SumBackward0>)
# loss 36 tensor(3.2860, grad_fn=<SumBackward0>)
# loss 37 tensor(3.2850, grad_fn=<SumBackward0>)
# loss 38 tensor(3.2849, grad_fn=<SumBackward0>)
# loss 39 tensor(3.2846, grad_fn=<SumBackward0>)
# loss 40 tensor(3.2833, grad_fn=<SumBackward0>)
# loss 41 tensor(3.2829, grad_fn=<SumBackward0>)
# loss 42 tensor(3.2816, grad_fn=<SumBackward0>)
# loss 43 tensor(3.2811, grad_fn=<SumBackward0>)
# loss 44 tensor(3.2801, grad_fn=<SumBackward0>)
# loss 45 tensor(3.2797, grad_fn=<SumBackward0>)
# loss 46 tensor(3.2785, grad_fn=<SumBackward0>)
# loss 47 tensor(3.2778, grad_fn=<SumBackward0>)
# loss 48 tensor(3.2769, grad_fn=<SumBackward0>)
# loss 49 tensor(3.2762, grad_fn=<SumBackward0>)
# loss 50 tensor(3.2752, grad_fn=<SumBackward0>)
# loss 51 tensor(3.2741, grad_fn=<SumBackward0>)
# loss 52 tensor(3.2737, grad_fn=<SumBackward0>)
# loss 53 tensor(3.2720, grad_fn=<SumBackward0>)
# loss 54 tensor(3.2718, grad_fn=<SumBackward0>)
# loss 55 tensor(3.2706, grad_fn=<SumBackward0>)
# loss 56 tensor(3.2694, grad_fn=<SumBackward0>)
# loss 57 tensor(3.2685, grad_fn=<SumBackward0>)
# loss 58 tensor(3.2680, grad_fn=<SumBackward0>)
# loss 59 tensor(3.2663, grad_fn=<SumBackward0>)
# loss 60 tensor(3.2641, grad_fn=<SumBackward0>)
# loss 61 tensor(3.2635, grad_fn=<SumBackward0>)
# loss 62 tensor(3.2624, grad_fn=<SumBackward0>)
# loss 63 tensor(3.2621, grad_fn=<SumBackward0>)
# loss 64 tensor(3.2611, grad_fn=<SumBackward0>)
# loss 65 tensor(3.2598, grad_fn=<SumBackward0>)
# loss 66 tensor(3.2585, grad_fn=<SumBackward0>)
# loss 67 tensor(3.2571, grad_fn=<SumBackward0>)
# loss 68 tensor(3.2553, grad_fn=<SumBackward0>)
# loss 69 tensor(3.2540, grad_fn=<SumBackward0>)
# loss 70 tensor(3.2536, grad_fn=<SumBackward0>)
# loss 71 tensor(3.2517, grad_fn=<SumBackward0>)
# loss 72 tensor(3.2510, grad_fn=<SumBackward0>)
# loss 73 tensor(3.2488, grad_fn=<SumBackward0>)
# loss 74 tensor(3.2478, grad_fn=<SumBackward0>)
# loss 75 tensor(3.2399, grad_fn=<SumBackward0>)
# loss 76 tensor(3.2377, grad_fn=<SumBackward0>)
# loss 77 tensor(3.2363, grad_fn=<SumBackward0>)
# loss 78 tensor(3.2343, grad_fn=<SumBackward0>)
# loss 79 tensor(3.2333, grad_fn=<SumBackward0>)
# loss 80 tensor(3.2303, grad_fn=<SumBackward0>)
# loss 81 tensor(3.2300, grad_fn=<SumBackward0>)
# loss 82 tensor(3.2263, grad_fn=<SumBackward0>)
# loss 83 tensor(3.2252, grad_fn=<SumBackward0>)
# loss 84 tensor(3.2241, grad_fn=<SumBackward0>)
# loss 85 tensor(3.2210, grad_fn=<SumBackward0>)
# loss 86 tensor(3.2193, grad_fn=<SumBackward0>)
# loss 87 tensor(3.2157, grad_fn=<SumBackward0>)
# loss 88 tensor(3.2152, grad_fn=<SumBackward0>)
# loss 89 tensor(3.2132, grad_fn=<SumBackward0>)
# loss 90 tensor(3.2124, grad_fn=<SumBackward0>)
# loss 91 tensor(3.2100, grad_fn=<SumBackward0>)
# loss 92 tensor(3.2067, grad_fn=<SumBackward0>)
# loss 93 tensor(3.2056, grad_fn=<SumBackward0>)
# loss 94 tensor(3.2018, grad_fn=<SumBackward0>)
# loss 95 tensor(3.2023, grad_fn=<SumBackward0>)
# loss 96 tensor(3.2001, grad_fn=<SumBackward0>)
# loss 97 tensor(3.1949, grad_fn=<SumBackward0>)
# loss 98 tensor(3.1942, grad_fn=<SumBackward0>)
# loss 99 tensor(3.1946, grad_fn=<SumBackward0>)
# loss 100 tensor(3.1731, grad_fn=<SumBackward0>)
# loss 101 tensor(3.1709, grad_fn=<SumBackward0>)
# loss 102 tensor(3.1682, grad_fn=<SumBackward0>)
# loss 103 tensor(3.1662, grad_fn=<SumBackward0>)
# loss 104 tensor(3.1634, grad_fn=<SumBackward0>)
# loss 105 tensor(3.1596, grad_fn=<SumBackward0>)
# loss 106 tensor(3.1539, grad_fn=<SumBackward0>)
# loss 107 tensor(3.1518, grad_fn=<SumBackward0>)
# loss 108 tensor(3.1503, grad_fn=<SumBackward0>)
# loss 109 tensor(3.1462, grad_fn=<SumBackward0>)
# loss 110 tensor(3.1430, grad_fn=<SumBackward0>)
# loss 111 tensor(3.1415, grad_fn=<SumBackward0>)
# loss 112 tensor(3.1386, grad_fn=<SumBackward0>)
# loss 113 tensor(3.1295, grad_fn=<SumBackward0>)
# loss 114 tensor(3.1278, grad_fn=<SumBackward0>)
# loss 115 tensor(3.1240, grad_fn=<SumBackward0>)
# loss 116 tensor(3.1216, grad_fn=<SumBackward0>)
# loss 117 tensor(3.1197, grad_fn=<SumBackward0>)
# loss 118 tensor(3.1183, grad_fn=<SumBackward0>)
# loss 119 tensor(3.1132, grad_fn=<SumBackward0>)
# loss 120 tensor(3.1092, grad_fn=<SumBackward0>)
# loss 121 tensor(3.1037, grad_fn=<SumBackward0>)
# loss 122 tensor(3.1032, grad_fn=<SumBackward0>)
# loss 123 tensor(3.0968, grad_fn=<SumBackward0>)
# loss 124 tensor(3.0932, grad_fn=<SumBackward0>)
# loss 125 tensor(3.0049, grad_fn=<SumBackward0>)
# loss 126 tensor(3.0000, grad_fn=<SumBackward0>)
# loss 127 tensor(2.9934, grad_fn=<SumBackward0>)
# loss 128 tensor(2.9874, grad_fn=<SumBackward0>)
# loss 129 tensor(2.9792, grad_fn=<SumBackward0>)
# loss 130 tensor(2.9709, grad_fn=<SumBackward0>)
# loss 131 tensor(2.9667, grad_fn=<SumBackward0>)
# loss 132 tensor(2.9568, grad_fn=<SumBackward0>)
# loss 133 tensor(2.9509, grad_fn=<SumBackward0>)
# loss 134 tensor(2.9416, grad_fn=<SumBackward0>)
# loss 135 tensor(2.9338, grad_fn=<SumBackward0>)
# loss 136 tensor(2.9292, grad_fn=<SumBackward0>)
# loss 137 tensor(2.9246, grad_fn=<SumBackward0>)
# loss 138 tensor(2.9141, grad_fn=<SumBackward0>)
# loss 139 tensor(2.9070, grad_fn=<SumBackward0>)
# loss 140 tensor(2.9007, grad_fn=<SumBackward0>)
# loss 141 tensor(2.8981, grad_fn=<SumBackward0>)
# loss 142 tensor(2.8916, grad_fn=<SumBackward0>)
# loss 143 tensor(2.8822, grad_fn=<SumBackward0>)
# loss 144 tensor(2.8728, grad_fn=<SumBackward0>)
# loss 145 tensor(2.8688, grad_fn=<SumBackward0>)
# loss 146 tensor(2.8590, grad_fn=<SumBackward0>)
# loss 147 tensor(2.8499, grad_fn=<SumBackward0>)
# loss 148 tensor(2.8429, grad_fn=<SumBackward0>)
# loss 149 tensor(2.8388, grad_fn=<SumBackward0>)
# loss 150 tensor(2.7673, grad_fn=<SumBackward0>)
# loss 151 tensor(2.7546, grad_fn=<SumBackward0>)
# loss 152 tensor(2.7476, grad_fn=<SumBackward0>)
# loss 153 tensor(2.7434, grad_fn=<SumBackward0>)
# loss 154 tensor(2.7323, grad_fn=<SumBackward0>)
# loss 155 tensor(2.7262, grad_fn=<SumBackward0>)
# loss 156 tensor(2.7182, grad_fn=<SumBackward0>)
# loss 157 tensor(2.7103, grad_fn=<SumBackward0>)
# loss 158 tensor(2.7002, grad_fn=<SumBackward0>)
# loss 159 tensor(2.6926, grad_fn=<SumBackward0>)
# loss 160 tensor(2.6830, grad_fn=<SumBackward0>)
# loss 161 tensor(2.6786, grad_fn=<SumBackward0>)
# loss 162 tensor(2.6720, grad_fn=<SumBackward0>)
# loss 163 tensor(2.6687, grad_fn=<SumBackward0>)
# loss 164 tensor(2.6532, grad_fn=<SumBackward0>)
# loss 165 tensor(2.6481, grad_fn=<SumBackward0>)
# loss 166 tensor(2.6402, grad_fn=<SumBackward0>)
# loss 167 tensor(2.6353, grad_fn=<SumBackward0>)
# loss 168 tensor(2.6286, grad_fn=<SumBackward0>)
# loss 169 tensor(2.6161, grad_fn=<SumBackward0>)
# loss 170 tensor(2.6082, grad_fn=<SumBackward0>)
# loss 171 tensor(2.6052, grad_fn=<SumBackward0>)
# loss 172 tensor(2.5993, grad_fn=<SumBackward0>)
# loss 173 tensor(2.5872, grad_fn=<SumBackward0>)
# loss 174 tensor(2.5850, grad_fn=<SumBackward0>)
# loss 175 tensor(2.3440, grad_fn=<SumBackward0>)
# loss 176 tensor(2.3326, grad_fn=<SumBackward0>)
# loss 177 tensor(2.3192, grad_fn=<SumBackward0>)
# loss 178 tensor(2.3052, grad_fn=<SumBackward0>)
# loss 179 tensor(2.2966, grad_fn=<SumBackward0>)
# loss 180 tensor(2.2949, grad_fn=<SumBackward0>)
# loss 181 tensor(2.2806, grad_fn=<SumBackward0>)
# loss 182 tensor(2.2791, grad_fn=<SumBackward0>)
# loss 183 tensor(2.2701, grad_fn=<SumBackward0>)
# loss 184 tensor(2.2664, grad_fn=<SumBackward0>)
# loss 185 tensor(2.2548, grad_fn=<SumBackward0>)
# loss 186 tensor(2.2562, grad_fn=<SumBackward0>)
# loss 187 tensor(2.2431, grad_fn=<SumBackward0>)
# loss 188 tensor(2.2373, grad_fn=<SumBackward0>)
# loss 189 tensor(2.2347, grad_fn=<SumBackward0>)
# loss 190 tensor(2.2265, grad_fn=<SumBackward0>)
# loss 191 tensor(2.2200, grad_fn=<SumBackward0>)
# loss 192 tensor(2.2101, grad_fn=<SumBackward0>)
# loss 193 tensor(2.2144, grad_fn=<SumBackward0>)
# loss 194 tensor(2.1954, grad_fn=<SumBackward0>)
# loss 195 tensor(2.2017, grad_fn=<SumBackward0>)
# loss 196 tensor(2.1930, grad_fn=<SumBackward0>)
# loss 197 tensor(2.1838, grad_fn=<SumBackward0>)
# loss 198 tensor(2.1824, grad_fn=<SumBackward0>)
# loss 199 tensor(2.1743, grad_fn=<SumBackward0>)
# loss 200 tensor(2.1751, grad_fn=<SumBackward0>)
# loss 201 tensor(2.1681, grad_fn=<SumBackward0>)
# loss 202 tensor(2.1594, grad_fn=<SumBackward0>)
# loss 203 tensor(2.1547, grad_fn=<SumBackward0>)
# loss 204 tensor(2.1529, grad_fn=<SumBackward0>)
# loss 205 tensor(2.1400, grad_fn=<SumBackward0>)
# loss 206 tensor(2.1386, grad_fn=<SumBackward0>)
# loss 207 tensor(2.1367, grad_fn=<SumBackward0>)
# loss 208 tensor(2.1297, grad_fn=<SumBackward0>)
# loss 209 tensor(2.1270, grad_fn=<SumBackward0>)
# loss 210 tensor(2.1200, grad_fn=<SumBackward0>)
# loss 211 tensor(2.1272, grad_fn=<SumBackward0>)
# loss 212 tensor(2.1198, grad_fn=<SumBackward0>)
# loss 213 tensor(2.1031, grad_fn=<SumBackward0>)
# loss 214 tensor(2.1084, grad_fn=<SumBackward0>)
# loss 215 tensor(2.1003, grad_fn=<SumBackward0>)
# loss 216 tensor(2.1035, grad_fn=<SumBackward0>)
# loss 217 tensor(2.0973, grad_fn=<SumBackward0>)
# loss 218 tensor(2.0911, grad_fn=<SumBackward0>)
# loss 219 tensor(2.0888, grad_fn=<SumBackward0>)
# loss 220 tensor(2.0877, grad_fn=<SumBackward0>)
# loss 221 tensor(2.0832, grad_fn=<SumBackward0>)
# loss 222 tensor(2.0808, grad_fn=<SumBackward0>)
# loss 223 tensor(2.0788, grad_fn=<SumBackward0>)
# loss 224 tensor(2.0703, grad_fn=<SumBackward0>)
# loss 225 tensor(2.0668, grad_fn=<SumBackward0>)
# loss 226 tensor(2.0701, grad_fn=<SumBackward0>)
# loss 227 tensor(2.0591, grad_fn=<SumBackward0>)
# loss 228 tensor(2.0582, grad_fn=<SumBackward0>)
# loss 229 tensor(2.0559, grad_fn=<SumBackward0>)
# loss 230 tensor(2.0463, grad_fn=<SumBackward0>)
# loss 231 tensor(2.0439, grad_fn=<SumBackward0>)
# loss 232 tensor(2.0452, grad_fn=<SumBackward0>)
# loss 233 tensor(2.0428, grad_fn=<SumBackward0>)
# loss 234 tensor(2.0400, grad_fn=<SumBackward0>)
# loss 235 tensor(2.0351, grad_fn=<SumBackward0>)
# loss 236 tensor(2.0346, grad_fn=<SumBackward0>)
# loss 237 tensor(2.0276, grad_fn=<SumBackward0>)
# loss 238 tensor(2.0270, grad_fn=<SumBackward0>)
# loss 239 tensor(2.0172, grad_fn=<SumBackward0>)
# loss 240 tensor(2.0204, grad_fn=<SumBackward0>)
# loss 241 tensor(2.0155, grad_fn=<SumBackward0>)
# loss 242 tensor(2.0149, grad_fn=<SumBackward0>)
# loss 243 tensor(2.0106, grad_fn=<SumBackward0>)
# loss 244 tensor(2.0044, grad_fn=<SumBackward0>)
# loss 245 tensor(2.0080, grad_fn=<SumBackward0>)
# loss 246 tensor(2.0027, grad_fn=<SumBackward0>)
# loss 247 tensor(2.0029, grad_fn=<SumBackward0>)
# loss 248 tensor(1.9980, grad_fn=<SumBackward0>)
# loss 249 tensor(2.0050, grad_fn=<SumBackward0>)
# loss 250 tensor(1.9303, grad_fn=<SumBackward0>)
# loss 251 tensor(1.9244, grad_fn=<SumBackward0>)
# loss 252 tensor(1.9211, grad_fn=<SumBackward0>)
# loss 253 tensor(1.9233, grad_fn=<SumBackward0>)
# loss 254 tensor(1.9228, grad_fn=<SumBackward0>)
# loss 255 tensor(1.9245, grad_fn=<SumBackward0>)
# loss 256 tensor(1.9153, grad_fn=<SumBackward0>)
# loss 257 tensor(1.9204, grad_fn=<SumBackward0>)
# loss 258 tensor(1.9160, grad_fn=<SumBackward0>)
# loss 259 tensor(1.9078, grad_fn=<SumBackward0>)
# loss 260 tensor(1.9099, grad_fn=<SumBackward0>)
# loss 261 tensor(1.9124, grad_fn=<SumBackward0>)
# loss 262 tensor(1.9036, grad_fn=<SumBackward0>)
# loss 263 tensor(1.9000, grad_fn=<SumBackward0>)
# loss 264 tensor(1.9061, grad_fn=<SumBackward0>)
# loss 265 tensor(1.9056, grad_fn=<SumBackward0>)
# loss 266 tensor(1.9034, grad_fn=<SumBackward0>)
# loss 267 tensor(1.9017, grad_fn=<SumBackward0>)
# loss 268 tensor(1.8980, grad_fn=<SumBackward0>)
# loss 269 tensor(1.8960, grad_fn=<SumBackward0>)
# loss 270 tensor(1.8935, grad_fn=<SumBackward0>)
# loss 271 tensor(1.8947, grad_fn=<SumBackward0>)
# loss 272 tensor(1.8938, grad_fn=<SumBackward0>)
# loss 273 tensor(1.8988, grad_fn=<SumBackward0>)
# loss 274 tensor(1.8942, grad_fn=<SumBackward0>)
# loss 275 tensor(1.8890, grad_fn=<SumBackward0>)
# loss 276 tensor(1.8904, grad_fn=<SumBackward0>)
# loss 277 tensor(1.8877, grad_fn=<SumBackward0>)
# loss 278 tensor(1.8859, grad_fn=<SumBackward0>)
# loss 279 tensor(1.8841, grad_fn=<SumBackward0>)
# loss 280 tensor(1.8867, grad_fn=<SumBackward0>)
# loss 281 tensor(1.8841, grad_fn=<SumBackward0>)
# loss 282 tensor(1.8790, grad_fn=<SumBackward0>)
# loss 283 tensor(1.8882, grad_fn=<SumBackward0>)
# loss 284 tensor(1.8829, grad_fn=<SumBackward0>)
# loss 285 tensor(1.8774, grad_fn=<SumBackward0>)
# loss 286 tensor(1.8820, grad_fn=<SumBackward0>)
# loss 287 tensor(1.8755, grad_fn=<SumBackward0>)
# loss 288 tensor(1.8742, grad_fn=<SumBackward0>)
# loss 289 tensor(1.8777, grad_fn=<SumBackward0>)
# loss 290 tensor(1.8730, grad_fn=<SumBackward0>)
# loss 291 tensor(1.8752, grad_fn=<SumBackward0>)
# loss 292 tensor(1.8695, grad_fn=<SumBackward0>)
# loss 293 tensor(1.8751, grad_fn=<SumBackward0>)
# loss 294 tensor(1.8672, grad_fn=<SumBackward0>)
# loss 295 tensor(1.8651, grad_fn=<SumBackward0>)
# loss 296 tensor(1.8706, grad_fn=<SumBackward0>)
# loss 297 tensor(1.8665, grad_fn=<SumBackward0>)
# loss 298 tensor(1.8688, grad_fn=<SumBackward0>)
# loss 299 tensor(1.8654, grad_fn=<SumBackward0>)
# loss 300 tensor(1.8348, grad_fn=<SumBackward0>)
# loss 301 tensor(1.8361, grad_fn=<SumBackward0>)
# loss 302 tensor(1.8311, grad_fn=<SumBackward0>)
# loss 303 tensor(1.8302, grad_fn=<SumBackward0>)
# loss 304 tensor(1.8359, grad_fn=<SumBackward0>)
# loss 305 tensor(1.8324, grad_fn=<SumBackward0>)
# loss 306 tensor(1.8303, grad_fn=<SumBackward0>)
# loss 307 tensor(1.8291, grad_fn=<SumBackward0>)
# loss 308 tensor(1.8322, grad_fn=<SumBackward0>)
# loss 309 tensor(1.8339, grad_fn=<SumBackward0>)
# loss 310 tensor(1.8283, grad_fn=<SumBackward0>)
# loss 311 tensor(1.8285, grad_fn=<SumBackward0>)
# loss 312 tensor(1.8289, grad_fn=<SumBackward0>)
# loss 313 tensor(1.8292, grad_fn=<SumBackward0>)
# loss 314 tensor(1.8331, grad_fn=<SumBackward0>)
# loss 315 tensor(1.8297, grad_fn=<SumBackward0>)
# loss 316 tensor(1.8263, grad_fn=<SumBackward0>)
# loss 317 tensor(1.8269, grad_fn=<SumBackward0>)
# loss 318 tensor(1.8268, grad_fn=<SumBackward0>)
# loss 319 tensor(1.8258, grad_fn=<SumBackward0>)
# loss 320 tensor(1.8142, grad_fn=<SumBackward0>)
# loss 321 tensor(1.8167, grad_fn=<SumBackward0>)
# loss 322 tensor(1.8116, grad_fn=<SumBackward0>)
# loss 323 tensor(1.8116, grad_fn=<SumBackward0>)
# loss 324 tensor(1.8146, grad_fn=<SumBackward0>)
# loss 325 tensor(1.8117, grad_fn=<SumBackward0>)
# loss 326 tensor(1.8144, grad_fn=<SumBackward0>)
# loss 327 tensor(1.8077, grad_fn=<SumBackward0>)
# loss 328 tensor(1.8118, grad_fn=<SumBackward0>)
# loss 329 tensor(1.8128, grad_fn=<SumBackward0>)
# loss 330 tensor(1.8141, grad_fn=<SumBackward0>)
# loss 331 tensor(1.8088, grad_fn=<SumBackward0>)
# loss 332 tensor(1.8109, grad_fn=<SumBackward0>)
# loss 333 tensor(1.8100, grad_fn=<SumBackward0>)
# loss 334 tensor(1.8096, grad_fn=<SumBackward0>)
# loss 335 tensor(1.8131, grad_fn=<SumBackward0>)
# loss 336 tensor(1.8103, grad_fn=<SumBackward0>)
# loss 337 tensor(1.8157, grad_fn=<SumBackward0>)
# loss 338 tensor(1.8087, grad_fn=<SumBackward0>)
# loss 339 tensor(1.8095, grad_fn=<SumBackward0>)
# loss 340 tensor(1.8113, grad_fn=<SumBackward0>)
# loss 341 tensor(1.8089, grad_fn=<SumBackward0>)
# loss 342 tensor(1.8129, grad_fn=<SumBackward0>)
# loss 343 tensor(1.8083, grad_fn=<SumBackward0>)
# loss 344 tensor(1.8124, grad_fn=<SumBackward0>)
# loss 345 tensor(1.8095, grad_fn=<SumBackward0>)
# loss 346 tensor(1.8113, grad_fn=<SumBackward0>)
# loss 347 tensor(1.8106, grad_fn=<SumBackward0>)
# loss 348 tensor(1.8079, grad_fn=<SumBackward0>)
# loss 349 tensor(1.8048, grad_fn=<SumBackward0>)
# loss 350 tensor(1.8078, grad_fn=<SumBackward0>)
# loss 351 tensor(1.8072, grad_fn=<SumBackward0>)
# loss 352 tensor(1.8089, grad_fn=<SumBackward0>)
# loss 353 tensor(1.8136, grad_fn=<SumBackward0>)
# loss 354 tensor(1.8109, grad_fn=<SumBackward0>)
# loss 355 tensor(1.8092, grad_fn=<SumBackward0>)
# loss 356 tensor(1.8077, grad_fn=<SumBackward0>)
# loss 357 tensor(1.8106, grad_fn=<SumBackward0>)
# loss 358 tensor(1.8100, grad_fn=<SumBackward0>)
# loss 359 tensor(1.8070, grad_fn=<SumBackward0>)
# loss 360 tensor(1.8061, grad_fn=<SumBackward0>)
# loss 361 tensor(1.8070, grad_fn=<SumBackward0>)
# loss 362 tensor(1.8089, grad_fn=<SumBackward0>)
# loss 363 tensor(1.8059, grad_fn=<SumBackward0>)
# loss 364 tensor(1.8113, grad_fn=<SumBackward0>)
# loss 365 tensor(1.8085, grad_fn=<SumBackward0>)
# loss 366 tensor(1.8089, grad_fn=<SumBackward0>)
# loss 367 tensor(1.8095, grad_fn=<SumBackward0>)
# loss 368 tensor(1.8082, grad_fn=<SumBackward0>)
# loss 369 tensor(1.8060, grad_fn=<SumBackward0>)
# loss 370 tensor(1.8093, grad_fn=<SumBackward0>)
# loss 371 tensor(1.8064, grad_fn=<SumBackward0>)
# loss 372 tensor(1.8053, grad_fn=<SumBackward0>)
# loss 373 tensor(1.8107, grad_fn=<SumBackward0>)
# loss 374 tensor(1.8055, grad_fn=<SumBackward0>)
# loss 375 tensor(1.8083, grad_fn=<SumBackward0>)
# loss 376 tensor(1.8050, grad_fn=<SumBackward0>)
# loss 377 tensor(1.8088, grad_fn=<SumBackward0>)
# loss 378 tensor(1.8075, grad_fn=<SumBackward0>)
# loss 379 tensor(1.8061, grad_fn=<SumBackward0>)
# loss 380 tensor(1.8130, grad_fn=<SumBackward0>)
# loss 381 tensor(1.8033, grad_fn=<SumBackward0>)
# loss 382 tensor(1.8050, grad_fn=<SumBackward0>)
# loss 383 tensor(1.8089, grad_fn=<SumBackward0>)
# loss 384 tensor(1.8082, grad_fn=<SumBackward0>)
# loss 385 tensor(1.8038, grad_fn=<SumBackward0>)
# loss 386 tensor(1.8034, grad_fn=<SumBackward0>)
# loss 387 tensor(1.8040, grad_fn=<SumBackward0>)
# loss 388 tensor(1.8094, grad_fn=<SumBackward0>)
# loss 389 tensor(1.8063, grad_fn=<SumBackward0>)
# loss 390 tensor(1.8042, grad_fn=<SumBackward0>)
# loss 391 tensor(1.8074, grad_fn=<SumBackward0>)
# loss 392 tensor(1.8076, grad_fn=<SumBackward0>)
# loss 393 tensor(1.8063, grad_fn=<SumBackward0>)
# loss 394 tensor(1.8054, grad_fn=<SumBackward0>)
# loss 395 tensor(1.8042, grad_fn=<SumBackward0>)
# loss 396 tensor(1.8048, grad_fn=<SumBackward0>)
# loss 397 tensor(1.8063, grad_fn=<SumBackward0>)
# loss 398 tensor(1.8070, grad_fn=<SumBackward0>)
# loss 399 tensor(1.8054, grad_fn=<SumBackward0>)
# loss 400 tensor(1.8077, grad_fn=<SumBackward0>)
# loss 401 tensor(1.8003, grad_fn=<SumBackward0>)
# loss 402 tensor(1.8002, grad_fn=<SumBackward0>)
# loss 403 tensor(1.8033, grad_fn=<SumBackward0>)
# loss 404 tensor(1.8049, grad_fn=<SumBackward0>)
# loss 405 tensor(1.8004, grad_fn=<SumBackward0>)
# loss 406 tensor(1.7992, grad_fn=<SumBackward0>)
# loss 407 tensor(1.7972, grad_fn=<SumBackward0>)
# loss 408 tensor(1.8006, grad_fn=<SumBackward0>)
# loss 409 tensor(1.8003, grad_fn=<SumBackward0>)
# loss 410 tensor(1.8011, grad_fn=<SumBackward0>)
# loss 411 tensor(1.8018, grad_fn=<SumBackward0>)
# loss 412 tensor(1.7982, grad_fn=<SumBackward0>)
# loss 413 tensor(1.7991, grad_fn=<SumBackward0>)
# loss 414 tensor(1.8003, grad_fn=<SumBackward0>)
# loss 415 tensor(1.8039, grad_fn=<SumBackward0>)
# loss 416 tensor(1.8001, grad_fn=<SumBackward0>)
# loss 417 tensor(1.7992, grad_fn=<SumBackward0>)
# loss 418 tensor(1.8017, grad_fn=<SumBackward0>)
# loss 419 tensor(1.8010, grad_fn=<SumBackward0>)
# loss 420 tensor(1.8015, grad_fn=<SumBackward0>)
# loss 421 tensor(1.7993, grad_fn=<SumBackward0>)
# loss 422 tensor(1.8029, grad_fn=<SumBackward0>)
# loss 423 tensor(1.7978, grad_fn=<SumBackward0>)
# loss 424 tensor(1.7997, grad_fn=<SumBackward0>)
# loss 425 tensor(1.8034, grad_fn=<SumBackward0>)
# loss 426 tensor(1.7972, grad_fn=<SumBackward0>)
# loss 427 tensor(1.7989, grad_fn=<SumBackward0>)
# loss 428 tensor(1.8006, grad_fn=<SumBackward0>)
# loss 429 tensor(1.8047, grad_fn=<SumBackward0>)
# loss 430 tensor(1.8007, grad_fn=<SumBackward0>)
# loss 431 tensor(1.7960, grad_fn=<SumBackward0>)
# loss 432 tensor(1.8014, grad_fn=<SumBackward0>)
# loss 433 tensor(1.8007, grad_fn=<SumBackward0>)
# loss 434 tensor(1.8017, grad_fn=<SumBackward0>)
# loss 435 tensor(1.8009, grad_fn=<SumBackward0>)
# loss 436 tensor(1.8019, grad_fn=<SumBackward0>)
# loss 437 tensor(1.7985, grad_fn=<SumBackward0>)
# loss 438 tensor(1.8005, grad_fn=<SumBackward0>)
# loss 439 tensor(1.8002, grad_fn=<SumBackward0>)
# loss 440 tensor(1.8009, grad_fn=<SumBackward0>)
# loss 441 tensor(1.8012, grad_fn=<SumBackward0>)
# loss 442 tensor(1.8012, grad_fn=<SumBackward0>)
# loss 443 tensor(1.7979, grad_fn=<SumBackward0>)
# loss 444 tensor(1.8005, grad_fn=<SumBackward0>)
# loss 445 tensor(1.8016, grad_fn=<SumBackward0>)
# loss 446 tensor(1.7989, grad_fn=<SumBackward0>)
# loss 447 tensor(1.7991, grad_fn=<SumBackward0>)
# loss 448 tensor(1.8035, grad_fn=<SumBackward0>)
# loss 449 tensor(1.7956, grad_fn=<SumBackward0>)
# loss 450 tensor(1.8001, grad_fn=<SumBackward0>)
# loss 451 tensor(1.8043, grad_fn=<SumBackward0>)
# loss 452 tensor(1.8024, grad_fn=<SumBackward0>)
# loss 453 tensor(1.8005, grad_fn=<SumBackward0>)
# loss 454 tensor(1.7985, grad_fn=<SumBackward0>)
# loss 455 tensor(1.7981, grad_fn=<SumBackward0>)
# loss 456 tensor(1.7986, grad_fn=<SumBackward0>)
# loss 457 tensor(1.7978, grad_fn=<SumBackward0>)
# loss 458 tensor(1.8006, grad_fn=<SumBackward0>)
# loss 459 tensor(1.7970, grad_fn=<SumBackward0>)
# loss 460 tensor(1.8008, grad_fn=<SumBackward0>)
# loss 461 tensor(1.7976, grad_fn=<SumBackward0>)
# loss 462 tensor(1.8045, grad_fn=<SumBackward0>)
# loss 463 tensor(1.8036, grad_fn=<SumBackward0>)
# loss 464 tensor(1.7989, grad_fn=<SumBackward0>)
# loss 465 tensor(1.7980, grad_fn=<SumBackward0>)
# loss 466 tensor(1.8005, grad_fn=<SumBackward0>)
# loss 467 tensor(1.8037, grad_fn=<SumBackward0>)
# loss 468 tensor(1.8018, grad_fn=<SumBackward0>)
# loss 469 tensor(1.7967, grad_fn=<SumBackward0>)
# loss 470 tensor(1.7989, grad_fn=<SumBackward0>)
# loss 471 tensor(1.7993, grad_fn=<SumBackward0>)
# loss 472 tensor(1.8007, grad_fn=<SumBackward0>)
# loss 473 tensor(1.7988, grad_fn=<SumBackward0>)
# loss 474 tensor(1.7991, grad_fn=<SumBackward0>)
# loss 475 tensor(1.7969, grad_fn=<SumBackward0>)
# loss 476 tensor(1.8006, grad_fn=<SumBackward0>)
# loss 477 tensor(1.8006, grad_fn=<SumBackward0>)
# loss 478 tensor(1.8029, grad_fn=<SumBackward0>)
# loss 479 tensor(1.7980, grad_fn=<SumBackward0>)
# loss 480 tensor(1.7967, grad_fn=<SumBackward0>)
# loss 481 tensor(1.7993, grad_fn=<SumBackward0>)
# loss 482 tensor(1.7963, grad_fn=<SumBackward0>)
# loss 483 tensor(1.8006, grad_fn=<SumBackward0>)
# loss 484 tensor(1.8000, grad_fn=<SumBackward0>)
# loss 485 tensor(1.7958, grad_fn=<SumBackward0>)
# loss 486 tensor(1.7978, grad_fn=<SumBackward0>)
# loss 487 tensor(1.8007, grad_fn=<SumBackward0>)
# loss 488 tensor(1.7992, grad_fn=<SumBackward0>)
# loss 489 tensor(1.7984, grad_fn=<SumBackward0>)
# loss 490 tensor(1.8018, grad_fn=<SumBackward0>)
# loss 491 tensor(1.7993, grad_fn=<SumBackward0>)
# loss 492 tensor(1.7990, grad_fn=<SumBackward0>)
# loss 493 tensor(1.7994, grad_fn=<SumBackward0>)
# loss 494 tensor(1.7993, grad_fn=<SumBackward0>)
# loss 495 tensor(1.7978, grad_fn=<SumBackward0>)
# loss 496 tensor(1.8004, grad_fn=<SumBackward0>)
# loss 497 tensor(1.8015, grad_fn=<SumBackward0>)
# loss 498 tensor(1.7995, grad_fn=<SumBackward0>)
# loss 499 tensor(1.7995, grad_fn=<SumBackward0>)

# %%
plt.figure(figsize=(20, 6))
plt.plot(loss_hist)
plt.grid(True)
plt.show()

# %%
gumbel_matrix = weight_feature.detach().max(dim=1)[1]
labels_pred = gumbel_matrix.data.numpy()

# %%
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=300, node_color="y", with_labels=True)
options = {
    'node_color': 'red',
    'node_size': 50,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.show()

print('Modularity for Zebra dataset is %.5f' %mod_calc(G,'Zebra',labels_pred))
color = []
for c in range(len(gumbel_matrix)):
    if(gumbel_matrix[c] == 0):
        color.append('r')
    elif(gumbel_matrix[c] == 1):
        color.append('g')
    elif(gumbel_matrix[c] == 2):
        color.append('teal')
    elif(gumbel_matrix[c] == 3):
        color.append('greenyellow')
    elif(gumbel_matrix[c] == 4):
        color.append('pink')
    elif(gumbel_matrix[c] == 5):
        color.append('dimgrey')
    elif(gumbel_matrix[c] == 6):
        color.append('peachpuff')
    elif(gumbel_matrix[c] == 7):
        color.append('gold')
    elif(gumbel_matrix[c] == 8):
        color.append('m')
    elif(gumbel_matrix[c] == 9):
        color.append('aqua')
    elif(gumbel_matrix[c] == 10):
        color.append('indianred')
    elif(gumbel_matrix[c] == 11):
        color.append('sienna')
plt.figure(figsize=(12, 12))
options = {
    'node_color': color,
    'node_size': 50,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx(G, pos=pos, node_size=350, node_color=color, with_labels=True)
plt.show()
# Out:
# /opt/anaconda/envs/Deepak/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# Modularity for Zebra dataset is 0.27023

# %%
import networkx as nx
from karateclub import MNMF,DANMF,EdMot,GEMSEC,SCD

G.add_edge(20,26)
model3 = EdMot()
model3.fit(G)
cluster_membership3 = model3.get_memberships()
clusters3 = cluster_membership3
labels_pred3 = list(clusters3.values())

print('Modularity of such partition for EdMot is %.6f' %get_modularity(G, labels_pred3))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for EdMot is 0.216000

# %%
model4 = GEMSEC(clusters=clusters_number)
model4.fit(G)
cluster_membership4 = model4.get_memberships()
clusters4 = cluster_membership4
labels_pred4 = list(clusters4.values())
print('Modularity of such partition for GEMSEC is %.6f' %get_modularity(G, labels_pred4))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for GEMSEC is 0.256417

# %%
model5 = SCD()
model5.fit(G)
cluster_membership5 = model5.get_memberships()
clusters5 = cluster_membership5
labels_pred5 = list(clusters5.values())
print('Modularity of such partition for SCD is %.6f' %get_modularity(G, labels_pred5))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for SCD is 0.196349

# %%
model1 = MNMF(clusters=2)
model1.fit(G)
cluster_membership1 = model1.get_memberships()
clusters1 = cluster_membership1
labels_pred1 = list(clusters1.values())
print('Modularity of such partition for MNMF is %.6f' %get_modularity(G, labels_pred1))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for MNMF is 0.265585

# %%
model2 = DANMF(layers=[32, clusters_number])
model2.fit(G)
cluster_membership2 = model2.get_memberships()
clusters2 = cluster_membership2
labels_pred2 = list(clusters2.values())
print('Modularity of such partition for DANMF is %.6f' %get_modularity(G, labels_pred2))
# Out:
# Calculating modularity for undirected graph
# Modularity of such partition for DANMF is 0.272202
